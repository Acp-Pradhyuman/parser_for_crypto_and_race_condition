# %%
import re

class CppCryptoVulnerabilityDetector:
    def __init__(self):
        self.vulnerabilities = []

    def detect_weak_crypto(self, code):
        # Detects weak cryptographic algorithms like MD5, SHA1, DES
        weak_crypto_patterns = [
            r"\bMD5\b",  # Detect MD5 usage
            r"\bSHA1\b",  # Detect SHA1 usage
            r"\bDES\b"  # Detect DES usage
        ]
        for pattern in weak_crypto_patterns:
            matches = re.finditer(pattern, code)
            for match in matches:
                self.vulnerabilities.append(f"Weak cryptographic algorithm ({match.group(0)}) detected at line {self.get_line_number(code, match.start())}")

    def detect_insecure_encryption_mode(self, code):
        # Detects insecure encryption modes like ECB
        ecb_pattern = r"\bECB\b"  # Detect ECB mode usage
        matches = re.finditer(ecb_pattern, code)
        for match in matches:
            self.vulnerabilities.append(f"Insecure encryption mode (ECB) detected at line {self.get_line_number(code, match.start())}")

    def detect_hardcoded_keys(self, code):
        # Detects hardcoded cryptographic keys in variable assignments
        key_pattern = r'\b(?:const\s+char\s*\*|std::string|char\s*\[\])\s*\w+\s*=\s*".*";'
        matches = re.finditer(key_pattern, code)
        for match in matches:
            if "key" in match.group(0).lower():
                self.vulnerabilities.append(f"Hardcoded cryptographic key detected at line {self.get_line_number(code, match.start())}")

    def detect_static_iv(self, code):
        # Detects static or hardcoded Initialization Vectors (IVs)
        iv_pattern = r'\b(?:const\s+char\s*\*|std::string|char\s*\[\])\s*\w+\s*=\s*".*";'
        matches = re.finditer(iv_pattern, code)
        for match in matches:
            if "iv" in match.group(0).lower():
                self.vulnerabilities.append(f"Static or hardcoded Initialization Vector (IV) detected at line {self.get_line_number(code, match.start())}")

    def detect_insecure_password_hashing(self, code):
        # Detects the use of raw cryptographic hash functions for password hashing
        password_hashing_patterns = [
            r"\bSHA256\b",  # Detect SHA-256 usage (insecure if used without salting)
            r"\bSHA512\b"  # Detect SHA-512 usage (insecure if used without salting)
        ]
        for pattern in password_hashing_patterns:
            matches = re.finditer(pattern, code)
            for match in matches:
                # Check if this is used in password-related code (heuristic check)
                if re.search(r'password', code[match.start() - 50:match.end() + 50], re.IGNORECASE):
                    self.vulnerabilities.append(f"Insecure password hashing using ({match.group(0)}) detected at line {self.get_line_number(code, match.start())}. Consider using a key derivation function like bcrypt or Argon2.")

    def get_line_number(self, code, index):
        # Returns the line number in the code for a given index
        return code[:index].count('\n') + 1

    def analyze_code(self, code):
        self.detect_weak_crypto(code)
        self.detect_insecure_encryption_mode(code)
        self.detect_hardcoded_keys(code)
        self.detect_static_iv(code)
        self.detect_insecure_password_hashing(code)

    def report(self):
        if self.vulnerabilities:
            print("Detected Vulnerabilities:")
            for vulnerability in self.vulnerabilities:
                print(vulnerability)
        else:
            print("No vulnerabilities detected.")

def main():
    # Example C++ code to analyze (this would normally be read from a file)
    cpp_code_to_analyze = """
#include <iostream>
#include <openssl/md5.h>
#include <openssl/aes.h>
#include <openssl/des.h>
#include <openssl/sha.h>
#include <string>

void hashPassword(const std::string& password) {
    unsigned char hash[SHA256_DIGEST_LENGTH];
    SHA256((unsigned char*)password.c_str(), password.length(), hash);  // Insecure: Raw SHA-256 used for password hashing
}

void encryptWithHardcodedKey(unsigned char* data) {
    const char* key = "hardcoded_secret_key";  // Vulnerable: Hardcoded key
    const char* iv = "fixed_iv_123456";  // Vulnerable: Hardcoded IV
    AES_KEY aes_key;
    AES_set_encrypt_key((unsigned char*)key, 128, &aes_key);
    AES_cbc_encrypt(data, data, 16, &aes_key, (unsigned char*)iv, AES_ENCRYPT);  // Vulnerable: CBC with a static IV
}

void encryptWithECB(unsigned char* data) {
    AES_KEY aes_key;
    AES_set_encrypt_key((unsigned char*)"another_key_1234", 128, &aes_key);
    AES_ecb_encrypt(data, data, &aes_key, AES_ENCRYPT);  // Vulnerable: Using ECB mode
}

int main() {
    std::string password = "mysecretpassword";
    hashPassword(password);

    unsigned char data[16] = {0};
    encryptWithHardcodedKey(data);
    encryptWithECB(data);

    return 0;
}
"""

    # Analyze the C++ code
    detector = CppCryptoVulnerabilityDetector()
    detector.analyze_code(cpp_code_to_analyze)
    detector.report()

if __name__ == "__main__":
    main()
# Out:
# Detected Vulnerabilities:
# Insecure encryption mode (ECB) detected at line 25
# Hardcoded cryptographic key detected at line 15
# Static or hardcoded Initialization Vector (IV) detected at line 16
# Insecure password hashing using (SHA256) detected at line 11. Consider using a key derivation function like bcrypt or Argon2.

# %%
import clang.cindex
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/test/sample.cpp'  # Update this with the correct file path

class CppVulnerabilityAnalyzer:
    def __init__(self, file_path):
        self.file_path = file_path
        self.index = clang.cindex.Index.create()
        self.vulnerabilities = []

    def analyze(self):
        translation_unit = self.index.parse(self.file_path)
        self.traverse_ast(translation_unit.cursor)

    def traverse_ast(self, node, thread_context=False, lock_acquired=False, lock_vars=None, func_defs=None):
        """
        Recursively traverse the AST and check for vulnerabilities.
        """
        # Initialize lock_vars and func_defs if not provided
        if lock_vars is None:
            lock_vars = set()
        if func_defs is None:
            func_defs = set()

        # Debugging: Print node kind, spelling, and line number
        if node.location.file:  # Only print nodes within the file being analyzed
            print(f"Visiting node: {node.kind} ({node.spelling}) at line {node.location.line}")

        # Detect function definitions to establish context
        if node.kind == clang.cindex.CursorKind.FUNCTION_DECL:
            func_defs.add(node.spelling)
            print(f"Function definition detected: {node.spelling} at line {node.location.line}")

        # Detect thread creation functions
        if node.kind == clang.cindex.CursorKind.CALL_EXPR and node.spelling in ["pthread_create", "std::thread"]:
            print(f"Thread-related function detected: {node.spelling} at line {node.location.line}")
            thread_context = True  # Entering a multithreaded context

        # Detect locking mechanisms (locking the mutex)
        if node.kind == clang.cindex.CursorKind.CALL_EXPR and ("lock" in node.spelling.lower() or "mutex" in node.spelling.lower()):
            print(f"Locking mechanism detected: {node.spelling} at line {node.location.line}")
            lock_acquired = True  # A lock has been acquired
            # Register lock variable
            for arg in node.get_arguments():
                lock_vars.add(arg.spelling)

        # Detect potential shared data access without locks
        if thread_context and not lock_acquired:
            self.detect_shared_data_access(node, lock_vars)

        # Detect weak cryptographic function usage
        self.detect_weak_crypto(node)

        # Recursively traverse all child nodes
        for child in node.get_children():
            # Pass down the context information
            self.traverse_ast(child, thread_context, lock_acquired, lock_vars, func_defs)

    def detect_shared_data_access(self, node, lock_vars):
        """
        Detect potential race conditions by checking shared data access without locks.
        """
        if node.kind == clang.cindex.CursorKind.DECL_REF_EXPR:
            # Check if the variable is a shared resource and not a lock variable
            if node.spelling not in lock_vars and node.spelling != "":
                print(f"Shared resource accessed without lock: {node.spelling} at line {node.location.line}")
                self.vulnerabilities.append(f"Potential race condition detected for resource '{node.spelling}' at line {node.location.line}")

    def detect_weak_crypto(self, node):
        """
        Detect the use of weak cryptographic algorithms.
        """
        if node.kind == clang.cindex.CursorKind.CALL_EXPR:
            # Check for weak cryptographic algorithms (MD5, SHA1)
            if node.spelling in ["MD5", "SHA1"]:  # Add more weak algorithms if needed
                print(f"Weak cryptographic algorithm ({node.spelling}) detected at line {node.location.line}")
                self.vulnerabilities.append(f"Weak cryptographic algorithm ({node.spelling}) detected at line {node.location.line}")

    def report(self):
        if self.vulnerabilities:
            print("\nDetected Vulnerabilities:")
            for vulnerability in self.vulnerabilities:
                print(vulnerability)
        else:
            print("\nNo vulnerabilities detected.")

if __name__ == "__main__":
    analyzer = CppVulnerabilityAnalyzer(file_path)
    analyzer.analyze()
    analyzer.report()
# Out:
# Streaming output truncated to the last 5000 lines.
# Visiting node: CursorKind.DECL_REF_EXPR (__builtin_nans) at line 1795
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 1795
# Visiting node: CursorKind.STRING_LITERAL ("") at line 1795
# Visiting node: CursorKind.CXX_METHOD (denorm_min) at line 1798
# Visiting node: CursorKind.COMPOUND_STMT () at line 1798
# Visiting node: CursorKind.RETURN_STMT () at line 1798
# Visiting node: CursorKind.FLOATING_LITERAL () at line 1798
# Visiting node: CursorKind.VAR_DECL (is_iec559) at line 1800
# Visiting node: CursorKind.BINARY_OPERATOR () at line 1801
# Visiting node: CursorKind.BINARY_OPERATOR () at line 1801
# Visiting node: CursorKind.UNEXPOSED_EXPR (has_infinity) at line 1801
# Visiting node: CursorKind.DECL_REF_EXPR (has_infinity) at line 1801
# Visiting node: CursorKind.UNEXPOSED_EXPR (has_quiet_NaN) at line 1801
# Visiting node: CursorKind.DECL_REF_EXPR (has_quiet_NaN) at line 1801
# Visiting node: CursorKind.BINARY_OPERATOR () at line 1801
# Visiting node: CursorKind.UNEXPOSED_EXPR (has_denorm) at line 1801
# Visiting node: CursorKind.UNEXPOSED_EXPR (has_denorm) at line 1801
# Visiting node: CursorKind.DECL_REF_EXPR (has_denorm) at line 1801
# Visiting node: CursorKind.UNEXPOSED_EXPR (denorm_present) at line 1801
# Visiting node: CursorKind.DECL_REF_EXPR (denorm_present) at line 1801
# Visiting node: CursorKind.VAR_DECL (is_bounded) at line 1802
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 1802
# Visiting node: CursorKind.VAR_DECL (is_modulo) at line 1803
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 1803
# Visiting node: CursorKind.VAR_DECL (traps) at line 1805
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 1805
# Visiting node: CursorKind.VAR_DECL (tinyness_before) at line 1806
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 1807
# Visiting node: CursorKind.VAR_DECL (round_style) at line 1808
# Visiting node: CursorKind.TYPE_REF (enum std::float_round_style) at line 1808
# Visiting node: CursorKind.DECL_REF_EXPR (round_to_nearest) at line 1809
# Visiting node: CursorKind.STRUCT_DECL (numeric_limits) at line 1818
# Visiting node: CursorKind.VAR_DECL (is_specialized) at line 1820
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 1820
# Visiting node: CursorKind.CXX_METHOD (min) at line 1823
# Visiting node: CursorKind.COMPOUND_STMT () at line 1823
# Visiting node: CursorKind.RETURN_STMT () at line 1823
# Visiting node: CursorKind.FLOATING_LITERAL () at line 1823
# Visiting node: CursorKind.CXX_METHOD (max) at line 1826
# Visiting node: CursorKind.COMPOUND_STMT () at line 1826
# Visiting node: CursorKind.RETURN_STMT () at line 1826
# Visiting node: CursorKind.FLOATING_LITERAL () at line 1826
# Visiting node: CursorKind.CXX_METHOD (lowest) at line 1830
# Visiting node: CursorKind.COMPOUND_STMT () at line 1830
# Visiting node: CursorKind.RETURN_STMT () at line 1830
# Visiting node: CursorKind.UNARY_OPERATOR () at line 1830
# Visiting node: CursorKind.FLOATING_LITERAL () at line 1830
# Visiting node: CursorKind.VAR_DECL (digits) at line 1833
# Visiting node: CursorKind.INTEGER_LITERAL () at line 1833
# Visiting node: CursorKind.VAR_DECL (digits10) at line 1834
# Visiting node: CursorKind.INTEGER_LITERAL () at line 1834
# Visiting node: CursorKind.VAR_DECL (max_digits10) at line 1836
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 1837
# Visiting node: CursorKind.PAREN_EXPR () at line 1837
# Visiting node: CursorKind.BINARY_OPERATOR () at line 1837
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 1837
# Visiting node: CursorKind.INTEGER_LITERAL () at line 1837
# Visiting node: CursorKind.BINARY_OPERATOR () at line 1837
# Visiting node: CursorKind.BINARY_OPERATOR () at line 1837
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 1837
# Visiting node: CursorKind.PAREN_EXPR () at line 1837
# Visiting node: CursorKind.INTEGER_LITERAL () at line 1837
# Visiting node: CursorKind.INTEGER_LITERAL () at line 1837
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 1837
# Visiting node: CursorKind.INTEGER_LITERAL () at line 1837
# Visiting node: CursorKind.VAR_DECL (is_signed) at line 1839
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 1839
# Visiting node: CursorKind.VAR_DECL (is_integer) at line 1840
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 1840
# Visiting node: CursorKind.VAR_DECL (is_exact) at line 1841
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 1841
# Visiting node: CursorKind.VAR_DECL (radix) at line 1842
# Visiting node: CursorKind.INTEGER_LITERAL () at line 1842
# Visiting node: CursorKind.CXX_METHOD (epsilon) at line 1845
# Visiting node: CursorKind.COMPOUND_STMT () at line 1845
# Visiting node: CursorKind.RETURN_STMT () at line 1845
# Visiting node: CursorKind.FLOATING_LITERAL () at line 1845
# Visiting node: CursorKind.CXX_METHOD (round_error) at line 1848
# Visiting node: CursorKind.COMPOUND_STMT () at line 1848
# Visiting node: CursorKind.RETURN_STMT () at line 1848
# Visiting node: CursorKind.FLOATING_LITERAL () at line 1848
# Visiting node: CursorKind.VAR_DECL (min_exponent) at line 1850
# Visiting node: CursorKind.PAREN_EXPR () at line 1850
# Visiting node: CursorKind.UNARY_OPERATOR () at line 1850
# Visiting node: CursorKind.INTEGER_LITERAL () at line 1850
# Visiting node: CursorKind.VAR_DECL (min_exponent10) at line 1851
# Visiting node: CursorKind.PAREN_EXPR () at line 1851
# Visiting node: CursorKind.UNARY_OPERATOR () at line 1851
# Visiting node: CursorKind.INTEGER_LITERAL () at line 1851
# Visiting node: CursorKind.VAR_DECL (max_exponent) at line 1852
# Visiting node: CursorKind.INTEGER_LITERAL () at line 1852
# Visiting node: CursorKind.VAR_DECL (max_exponent10) at line 1853
# Visiting node: CursorKind.INTEGER_LITERAL () at line 1853
# Visiting node: CursorKind.VAR_DECL (has_infinity) at line 1855
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 1855
# Visiting node: CursorKind.INTEGER_LITERAL () at line 1855
# Visiting node: CursorKind.VAR_DECL (has_quiet_NaN) at line 1856
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 1856
# Visiting node: CursorKind.INTEGER_LITERAL () at line 1856
# Visiting node: CursorKind.VAR_DECL (has_signaling_NaN) at line 1857
# Visiting node: CursorKind.UNEXPOSED_EXPR (has_quiet_NaN) at line 1857
# Visiting node: CursorKind.DECL_REF_EXPR (has_quiet_NaN) at line 1857
# Visiting node: CursorKind.VAR_DECL (has_denorm) at line 1858
# Visiting node: CursorKind.TYPE_REF (enum std::float_denorm_style) at line 1858
# Visiting node: CursorKind.CONDITIONAL_OPERATOR () at line 1859
# Visiting node: CursorKind.CXX_FUNCTIONAL_CAST_EXPR () at line 1859
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 1859
# Visiting node: CursorKind.INTEGER_LITERAL () at line 1859
# Visiting node: CursorKind.DECL_REF_EXPR (denorm_present) at line 1859
# Visiting node: CursorKind.DECL_REF_EXPR (denorm_absent) at line 1859
# Visiting node: CursorKind.VAR_DECL (has_denorm_loss) at line 1860
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 1861
# Visiting node: CursorKind.CXX_METHOD (infinity) at line 1864
# Visiting node: CursorKind.COMPOUND_STMT () at line 1864
# Visiting node: CursorKind.RETURN_STMT () at line 1864
# Visiting node: CursorKind.CALL_EXPR (__builtin_huge_vall) at line 1864
# Visiting node: CursorKind.UNEXPOSED_EXPR (__builtin_huge_vall) at line 1864
# Visiting node: CursorKind.DECL_REF_EXPR (__builtin_huge_vall) at line 1864
# Visiting node: CursorKind.CXX_METHOD (quiet_NaN) at line 1867
# Visiting node: CursorKind.COMPOUND_STMT () at line 1867
# Visiting node: CursorKind.RETURN_STMT () at line 1867
# Visiting node: CursorKind.CALL_EXPR (__builtin_nanl) at line 1867
# Visiting node: CursorKind.UNEXPOSED_EXPR (__builtin_nanl) at line 1867
# Visiting node: CursorKind.DECL_REF_EXPR (__builtin_nanl) at line 1867
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 1867
# Visiting node: CursorKind.STRING_LITERAL ("") at line 1867
# Visiting node: CursorKind.CXX_METHOD (signaling_NaN) at line 1870
# Visiting node: CursorKind.COMPOUND_STMT () at line 1870
# Visiting node: CursorKind.RETURN_STMT () at line 1870
# Visiting node: CursorKind.CALL_EXPR (__builtin_nansl) at line 1870
# Visiting node: CursorKind.UNEXPOSED_EXPR (__builtin_nansl) at line 1870
# Visiting node: CursorKind.DECL_REF_EXPR (__builtin_nansl) at line 1870
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 1870
# Visiting node: CursorKind.STRING_LITERAL ("") at line 1870
# Visiting node: CursorKind.CXX_METHOD (denorm_min) at line 1873
# Visiting node: CursorKind.COMPOUND_STMT () at line 1873
# Visiting node: CursorKind.RETURN_STMT () at line 1873
# Visiting node: CursorKind.FLOATING_LITERAL () at line 1873
# Visiting node: CursorKind.VAR_DECL (is_iec559) at line 1875
# Visiting node: CursorKind.BINARY_OPERATOR () at line 1876
# Visiting node: CursorKind.BINARY_OPERATOR () at line 1876
# Visiting node: CursorKind.UNEXPOSED_EXPR (has_infinity) at line 1876
# Visiting node: CursorKind.DECL_REF_EXPR (has_infinity) at line 1876
# Visiting node: CursorKind.UNEXPOSED_EXPR (has_quiet_NaN) at line 1876
# Visiting node: CursorKind.DECL_REF_EXPR (has_quiet_NaN) at line 1876
# Visiting node: CursorKind.BINARY_OPERATOR () at line 1876
# Visiting node: CursorKind.UNEXPOSED_EXPR (has_denorm) at line 1876
# Visiting node: CursorKind.UNEXPOSED_EXPR (has_denorm) at line 1876
# Visiting node: CursorKind.DECL_REF_EXPR (has_denorm) at line 1876
# Visiting node: CursorKind.UNEXPOSED_EXPR (denorm_present) at line 1876
# Visiting node: CursorKind.DECL_REF_EXPR (denorm_present) at line 1876
# Visiting node: CursorKind.VAR_DECL (is_bounded) at line 1877
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 1877
# Visiting node: CursorKind.VAR_DECL (is_modulo) at line 1878
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 1878
# Visiting node: CursorKind.VAR_DECL (traps) at line 1880
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 1880
# Visiting node: CursorKind.VAR_DECL (tinyness_before) at line 1881
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 1882
# Visiting node: CursorKind.VAR_DECL (round_style) at line 1883
# Visiting node: CursorKind.TYPE_REF (enum std::float_round_style) at line 1883
# Visiting node: CursorKind.DECL_REF_EXPR (round_to_nearest) at line 1884
# Visiting node: CursorKind.NAMESPACE (std) at line 58
# Visiting node: CursorKind.USING_DECLARATION (clock_t) at line 60
# Visiting node: CursorKind.OVERLOADED_DECL_REF (clock_t) at line 60
# Visiting node: CursorKind.USING_DECLARATION (time_t) at line 61
# Visiting node: CursorKind.OVERLOADED_DECL_REF (time_t) at line 61
# Visiting node: CursorKind.USING_DECLARATION (tm) at line 62
# Visiting node: CursorKind.OVERLOADED_DECL_REF (tm) at line 62
# Visiting node: CursorKind.USING_DECLARATION (clock) at line 64
# Visiting node: CursorKind.OVERLOADED_DECL_REF (clock) at line 64
# Visiting node: CursorKind.USING_DECLARATION (difftime) at line 65
# Visiting node: CursorKind.OVERLOADED_DECL_REF (difftime) at line 65
# Visiting node: CursorKind.USING_DECLARATION (mktime) at line 66
# Visiting node: CursorKind.OVERLOADED_DECL_REF (mktime) at line 66
# Visiting node: CursorKind.USING_DECLARATION (time) at line 67
# Visiting node: CursorKind.OVERLOADED_DECL_REF (time) at line 67
# Visiting node: CursorKind.USING_DECLARATION (asctime) at line 68
# Visiting node: CursorKind.OVERLOADED_DECL_REF (asctime) at line 68
# Visiting node: CursorKind.USING_DECLARATION (ctime) at line 69
# Visiting node: CursorKind.OVERLOADED_DECL_REF (ctime) at line 69
# Visiting node: CursorKind.USING_DECLARATION (gmtime) at line 70
# Visiting node: CursorKind.OVERLOADED_DECL_REF (gmtime) at line 70
# Visiting node: CursorKind.USING_DECLARATION (localtime) at line 71
# Visiting node: CursorKind.OVERLOADED_DECL_REF (localtime) at line 71
# Visiting node: CursorKind.USING_DECLARATION (strftime) at line 72
# Visiting node: CursorKind.OVERLOADED_DECL_REF (strftime) at line 72
# Visiting node: CursorKind.NAMESPACE (std) at line 77
# Visiting node: CursorKind.USING_DECLARATION (timespec) at line 79
# Visiting node: CursorKind.OVERLOADED_DECL_REF (timespec) at line 79
# Visiting node: CursorKind.USING_DECLARATION (timespec_get) at line 80
# Visiting node: CursorKind.OVERLOADED_DECL_REF (timespec_get) at line 80
# Visiting node: CursorKind.NAMESPACE (std) at line 42
# Visiting node: CursorKind.VISIBILITY_ATTR (default) at line 42
# Visiting node: CursorKind.NAMESPACE (__parse_int) at line 46
# Visiting node: CursorKind.CLASS_TEMPLATE (_Digit) at line 49
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 48
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Dig) at line 48
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 52
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 51
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 52
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 52
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 58
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 57
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 58
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 58
# Visiting node: CursorKind.CLASS_TEMPLATE (_Digit_impl) at line 64
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 63
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Val) at line 63
# Visiting node: CursorKind.STATIC_ASSERT () at line 66
# Visiting node: CursorKind.BINARY_OPERATOR () at line 66
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 66
# Visiting node: CursorKind.DECL_REF_EXPR (_Val) at line 66
# Visiting node: CursorKind.STRING_LITERAL ("invalid digit") at line 66
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 71
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 70
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 71
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 71
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 2>) at line 71
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 71
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 71
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 71
# Visiting node: CursorKind.INTEGER_LITERAL () at line 71
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 75
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 74
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 75
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 75
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 3>) at line 75
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 75
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 75
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 75
# Visiting node: CursorKind.INTEGER_LITERAL () at line 75
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 79
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 78
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 79
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 79
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 4>) at line 79
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 79
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 79
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 79
# Visiting node: CursorKind.INTEGER_LITERAL () at line 79
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 83
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 82
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 83
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 83
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 5>) at line 83
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 83
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 83
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 83
# Visiting node: CursorKind.INTEGER_LITERAL () at line 83
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 87
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 86
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 87
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 87
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 6>) at line 87
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 87
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 87
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 87
# Visiting node: CursorKind.INTEGER_LITERAL () at line 87
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 91
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 90
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 91
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 91
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 7>) at line 91
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 91
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 91
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 91
# Visiting node: CursorKind.INTEGER_LITERAL () at line 91
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 95
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 94
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 95
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 95
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 8>) at line 95
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 95
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 95
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 95
# Visiting node: CursorKind.INTEGER_LITERAL () at line 95
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 99
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 98
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 99
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 99
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 9>) at line 99
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 99
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 99
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 99
# Visiting node: CursorKind.INTEGER_LITERAL () at line 99
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 103
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 102
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 103
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 103
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 10>) at line 103
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 103
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 103
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 103
# Visiting node: CursorKind.INTEGER_LITERAL () at line 103
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 107
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 106
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 107
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 107
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 10>) at line 107
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 107
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 107
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 107
# Visiting node: CursorKind.INTEGER_LITERAL () at line 107
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 111
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 110
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 111
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 111
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 11>) at line 111
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 111
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 111
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 111
# Visiting node: CursorKind.INTEGER_LITERAL () at line 111
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 115
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 114
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 115
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 115
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 11>) at line 115
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 115
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 115
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 115
# Visiting node: CursorKind.INTEGER_LITERAL () at line 115
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 119
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 118
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 119
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 119
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 12>) at line 119
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 119
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 119
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 119
# Visiting node: CursorKind.INTEGER_LITERAL () at line 119
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 123
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 122
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 123
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 123
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 12>) at line 123
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 123
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 123
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 123
# Visiting node: CursorKind.INTEGER_LITERAL () at line 123
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 127
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 126
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 127
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 127
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 13>) at line 127
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 127
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 127
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 127
# Visiting node: CursorKind.INTEGER_LITERAL () at line 127
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 131
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 130
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 131
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 131
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 13>) at line 131
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 131
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 131
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 131
# Visiting node: CursorKind.INTEGER_LITERAL () at line 131
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 135
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 134
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 135
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 135
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 14>) at line 135
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 135
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 135
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 135
# Visiting node: CursorKind.INTEGER_LITERAL () at line 135
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 139
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 138
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 139
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 139
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 14>) at line 139
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 139
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 139
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 139
# Visiting node: CursorKind.INTEGER_LITERAL () at line 139
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 143
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 142
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 143
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 143
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 15>) at line 143
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 143
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 143
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 143
# Visiting node: CursorKind.INTEGER_LITERAL () at line 143
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 147
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 146
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 147
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 147
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Digit_impl<_Base, 15>) at line 147
# Visiting node: CursorKind.TEMPLATE_REF (_Digit_impl) at line 147
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 147
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 147
# Visiting node: CursorKind.INTEGER_LITERAL () at line 147
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Digit) at line 152
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 151
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 152
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 152
# Visiting node: CursorKind.CLASS_TEMPLATE (_Power_help) at line 163
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 162
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Dig) at line 162
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Digs) at line 162
# Visiting node: CursorKind.TYPE_ALIAS_DECL (__next) at line 165
# Visiting node: CursorKind.TEMPLATE_REF (_Power_help) at line 165
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 165
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 165
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 165
# Visiting node: CursorKind.TYPE_ALIAS_DECL (__valid_digit) at line 166
# Visiting node: CursorKind.TEMPLATE_REF (_Digit) at line 166
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 166
# Visiting node: CursorKind.DECL_REF_EXPR (_Dig) at line 166
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Power_help) at line 172
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 171
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Dig) at line 171
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 172
# Visiting node: CursorKind.DECL_REF_EXPR (_Dig) at line 172
# Visiting node: CursorKind.TYPE_ALIAS_DECL (__valid_digit) at line 174
# Visiting node: CursorKind.TEMPLATE_REF (_Digit) at line 174
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 174
# Visiting node: CursorKind.DECL_REF_EXPR (_Dig) at line 174
# Visiting node: CursorKind.CLASS_TEMPLATE (_Power) at line 179
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 178
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Digs) at line 178
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Power_help<_Base, _Digs...>::type) at line 179
# Visiting node: CursorKind.TEMPLATE_REF (_Power_help) at line 179
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 179
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 179
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 179
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Power) at line 183
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 182
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 183
# Visiting node: CursorKind.CLASS_TEMPLATE (_Number_help) at line 189
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 188
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Pow) at line 188
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Dig) at line 188
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Digs) at line 188
# Visiting node: CursorKind.TYPE_ALIAS_DECL (__digit) at line 191
# Visiting node: CursorKind.TEMPLATE_REF (_Digit) at line 191
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 191
# Visiting node: CursorKind.DECL_REF_EXPR (_Dig) at line 191
# Visiting node: CursorKind.TYPE_ALIAS_DECL (__valid_digit) at line 192
# Visiting node: CursorKind.TYPE_REF (std::__parse_int::_Number_help::__digit) at line 192
# Visiting node: CursorKind.TYPE_ALIAS_DECL (__next) at line 193
# Visiting node: CursorKind.TEMPLATE_REF (_Number_help) at line 193
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 193
# Visiting node: CursorKind.CONDITIONAL_OPERATOR () at line 194
# Visiting node: CursorKind.DECL_REF_EXPR () at line 194
# Visiting node: CursorKind.TYPE_REF (std::__parse_int::_Number_help::__valid_digit) at line 194
# Visiting node: CursorKind.BINARY_OPERATOR () at line 194
# Visiting node: CursorKind.DECL_REF_EXPR (_Pow) at line 194
# Visiting node: CursorKind.UNEXPOSED_EXPR (_Base) at line 194
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 194
# Visiting node: CursorKind.DECL_REF_EXPR (_Pow) at line 194
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 195
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 195
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Number_help) at line 203
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 202
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Pow) at line 202
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Dig) at line 202
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Digs) at line 202
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 203
# Visiting node: CursorKind.DECL_REF_EXPR (_Pow) at line 203
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 203
# Visiting node: CursorKind.DECL_REF_EXPR (_Dig) at line 203
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 203
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 203
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Number_help<_Base, _Pow, _Dig, _Digs...>) at line 204
# Visiting node: CursorKind.TEMPLATE_REF (_Number_help) at line 204
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 204
# Visiting node: CursorKind.DECL_REF_EXPR (_Pow) at line 204
# Visiting node: CursorKind.DECL_REF_EXPR (_Dig) at line 204
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 204
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 204
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Number_help) at line 209
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 208
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Dig) at line 208
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 209
# Visiting node: CursorKind.INTEGER_LITERAL () at line 209
# Visiting node: CursorKind.DECL_REF_EXPR (_Dig) at line 209
# Visiting node: CursorKind.CLASS_TEMPLATE (_Number) at line 215
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 214
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Digs) at line 214
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Number_help<_Base, _Power<_Base, _Digs...>::value, _Digs...>::type) at line 216
# Visiting node: CursorKind.TEMPLATE_REF (_Number_help) at line 216
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 216
# Visiting node: CursorKind.DECL_REF_EXPR () at line 216
# Visiting node: CursorKind.TEMPLATE_REF (_Power) at line 216
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 216
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 216
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 216
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 216
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 216
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Number) at line 220
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Base) at line 219
# Visiting node: CursorKind.DECL_REF_EXPR (_Base) at line 220
# Visiting node: CursorKind.CLASS_TEMPLATE (_Parse_int) at line 227
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Digs) at line 226
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Parse_int) at line 230
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Digs) at line 229
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 230
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 230
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 230
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 230
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Number<2U, _Digs...>::type) at line 231
# Visiting node: CursorKind.TEMPLATE_REF (_Number) at line 231
# Visiting node: CursorKind.INTEGER_LITERAL () at line 231
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 231
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 231
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Parse_int) at line 235
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Digs) at line 234
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 235
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 235
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 235
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 235
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Number<2U, _Digs...>::type) at line 236
# Visiting node: CursorKind.TEMPLATE_REF (_Number) at line 236
# Visiting node: CursorKind.INTEGER_LITERAL () at line 236
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 236
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 236
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Parse_int) at line 240
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Digs) at line 239
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 240
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 240
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 240
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 240
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Number<16U, _Digs...>::type) at line 241
# Visiting node: CursorKind.TEMPLATE_REF (_Number) at line 241
# Visiting node: CursorKind.INTEGER_LITERAL () at line 241
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 241
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 241
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Parse_int) at line 245
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Digs) at line 244
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 245
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 245
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 245
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 245
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Number<16U, _Digs...>::type) at line 246
# Visiting node: CursorKind.TEMPLATE_REF (_Number) at line 246
# Visiting node: CursorKind.INTEGER_LITERAL () at line 246
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 246
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 246
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Parse_int) at line 250
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Digs) at line 249
# Visiting node: CursorKind.CHARACTER_LITERAL () at line 250
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 250
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 250
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Number<8U, _Digs...>::type) at line 251
# Visiting node: CursorKind.TEMPLATE_REF (_Number) at line 251
# Visiting node: CursorKind.INTEGER_LITERAL () at line 251
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 251
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 251
# Visiting node: CursorKind.CLASS_TEMPLATE (_Parse_int) at line 255
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Digs) at line 254
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Number<10U, _Digs...>::type) at line 256
# Visiting node: CursorKind.TEMPLATE_REF (_Number) at line 256
# Visiting node: CursorKind.INTEGER_LITERAL () at line 256
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 256
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 256
# Visiting node: CursorKind.NAMESPACE (__select_int) at line 262
# Visiting node: CursorKind.CLASS_TEMPLATE (_Select_int_base) at line 265
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Val) at line 264
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Ints) at line 264
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Select_int_base) at line 268
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Val) at line 267
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_IntType) at line 267
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Ints) at line 267
# Visiting node: CursorKind.DECL_REF_EXPR (_Val) at line 268
# Visiting node: CursorKind.TYPE_REF (_IntType) at line 268
# Visiting node: CursorKind.TYPE_REF (_Ints) at line 268
# Visiting node: CursorKind.CXX_BASE_SPECIFIER (_Select_int_base<_Val, _Ints...>) at line 271
# Visiting node: CursorKind.TEMPLATE_REF (_Select_int_base) at line 271
# Visiting node: CursorKind.DECL_REF_EXPR (_Val) at line 271
# Visiting node: CursorKind.TYPE_REF (_Ints) at line 271
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (_Select_int_base) at line 275
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Val) at line 274
# Visiting node: CursorKind.DECL_REF_EXPR (_Val) at line 275
# Visiting node: CursorKind.TYPE_ALIAS_TEMPLATE_DECL (_Select_int) at line 279
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_Digs) at line 278
# Visiting node: CursorKind.TYPE_ALIAS_DECL (_Select_int) at line 279
# Visiting node: CursorKind.TEMPLATE_REF (_Select_int_base) at line 279
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 280
# Visiting node: CursorKind.DECL_REF_EXPR () at line 280
# Visiting node: CursorKind.NAMESPACE_REF (__parse_int) at line 280
# Visiting node: CursorKind.TEMPLATE_REF (_Parse_int) at line 280
# Visiting node: CursorKind.PACK_EXPANSION_EXPR () at line 280
# Visiting node: CursorKind.DECL_REF_EXPR (_Digs) at line 280
# Visiting node: CursorKind.NAMESPACE (std) at line 49
# Visiting node: CursorKind.VISIBILITY_ATTR (default) at line 49
# Visiting node: CursorKind.NAMESPACE (filesystem) at line 54
# Visiting node: CursorKind.STRUCT_DECL (__file_clock) at line 54
# Visiting node: CursorKind.UNEXPOSED_DECL () at line 54
# Visiting node: CursorKind.NAMESPACE (chrono) at line 70
# Visiting node: CursorKind.CLASS_TEMPLATE (duration) at line 77
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Rep) at line 76
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Period) at line 76
# Visiting node: CursorKind.CLASS_TEMPLATE (time_point) at line 81
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Clock) at line 80
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Dur) at line 80
# Visiting node: CursorKind.TYPE_REF (_Clock) at line 80
# Visiting node: CursorKind.CLASS_TEMPLATE (__duration_common_type) at line 93
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_CT) at line 92
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Period1) at line 92
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Period2) at line 92
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER () at line 92
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (common_type) at line 118
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Rep1) at line 117
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Period1) at line 117
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Rep2) at line 117
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Period2) at line 117
# Visiting node: CursorKind.NAMESPACE_REF (chrono) at line 118
# Visiting node: CursorKind.TEMPLATE_REF (duration) at line 118
# Visiting node: CursorKind.TYPE_REF (_Rep1) at line 118
# Visiting node: CursorKind.TYPE_REF (_Period1) at line 118
# Visiting node: CursorKind.NAMESPACE_REF (chrono) at line 119
# Visiting node: CursorKind.TEMPLATE_REF (duration) at line 119
# Visiting node: CursorKind.TYPE_REF (_Rep2) at line 119
# Visiting node: CursorKind.TYPE_REF (_Period2) at line 119
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (common_type) at line 127
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Rep) at line 126
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Period) at line 126
# Visiting node: CursorKind.NAMESPACE_REF (chrono) at line 127
# Visiting node: CursorKind.TEMPLATE_REF (duration) at line 127
# Visiting node: CursorKind.TYPE_REF (_Rep) at line 127
# Visiting node: CursorKind.TYPE_REF (_Period) at line 127
# Visiting node: CursorKind.NAMESPACE_REF (chrono) at line 128
# Visiting node: CursorKind.TEMPLATE_REF (duration) at line 128
# Visiting node: CursorKind.TYPE_REF (_Rep) at line 128
# Visiting node: CursorKind.TYPE_REF (_Period) at line 128
# Visiting node: CursorKind.TYPE_ALIAS_DECL (type) at line 130
# Visiting node: CursorKind.NAMESPACE_REF (chrono) at line 130
# Visiting node: CursorKind.TEMPLATE_REF (duration) at line 130
# Visiting node: CursorKind.TEMPLATE_REF (common_type) at line 130
# Visiting node: CursorKind.TYPE_REF (_Rep) at line 130
# Visiting node: CursorKind.TYPE_REF (_Period) at line 131
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (common_type) at line 136
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Rep) at line 135
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Period) at line 135
# Visiting node: CursorKind.NAMESPACE_REF (chrono) at line 136
# Visiting node: CursorKind.TEMPLATE_REF (duration) at line 136
# Visiting node: CursorKind.TYPE_REF (_Rep) at line 136
# Visiting node: CursorKind.TYPE_REF (_Period) at line 136
# Visiting node: CursorKind.TYPE_ALIAS_DECL (type) at line 138
# Visiting node: CursorKind.NAMESPACE_REF (chrono) at line 138
# Visiting node: CursorKind.TEMPLATE_REF (duration) at line 138
# Visiting node: CursorKind.TEMPLATE_REF (common_type) at line 138
# Visiting node: CursorKind.TYPE_REF (_Rep) at line 138
# Visiting node: CursorKind.TYPE_REF (_Period) at line 139
# Visiting node: CursorKind.CLASS_TEMPLATE (__timepoint_common_type) at line 148
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_CT) at line 147
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Clock) at line 147
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER () at line 147
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (common_type) at line 164
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Clock) at line 163
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Duration1) at line 163
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Duration2) at line 163
# Visiting node: CursorKind.NAMESPACE_REF (chrono) at line 164
# Visiting node: CursorKind.TEMPLATE_REF (time_point) at line 164
# Visiting node: CursorKind.TYPE_REF (_Clock) at line 164
# Visiting node: CursorKind.TYPE_REF (_Duration1) at line 164
# Visiting node: CursorKind.NAMESPACE_REF (chrono) at line 165
# Visiting node: CursorKind.TEMPLATE_REF (time_point) at line 165
# Visiting node: CursorKind.TYPE_REF (_Clock) at line 165
# Visiting node: CursorKind.TYPE_REF (_Duration2) at line 165
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (common_type) at line 171
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Clock) at line 170
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Duration) at line 170
# Visiting node: CursorKind.NAMESPACE_REF (chrono) at line 171
# Visiting node: CursorKind.TEMPLATE_REF (time_point) at line 171
# Visiting node: CursorKind.TYPE_REF (_Clock) at line 171
# Visiting node: CursorKind.TYPE_REF (_Duration) at line 171
# Visiting node: CursorKind.NAMESPACE_REF (chrono) at line 172
# Visiting node: CursorKind.TEMPLATE_REF (time_point) at line 172
# Visiting node: CursorKind.TYPE_REF (_Clock) at line 172
# Visiting node: CursorKind.TYPE_REF (_Duration) at line 172
# Visiting node: CursorKind.TYPE_ALIAS_DECL (type) at line 173
# Visiting node: CursorKind.NAMESPACE_REF (chrono) at line 173
# Visiting node: CursorKind.TEMPLATE_REF (time_point) at line 173
# Visiting node: CursorKind.TYPE_REF (_Clock) at line 173
# Visiting node: CursorKind.TYPE_REF (_Duration) at line 173
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (common_type) at line 177
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Clock) at line 176
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Duration) at line 176
# Visiting node: CursorKind.NAMESPACE_REF (chrono) at line 177
# Visiting node: CursorKind.TEMPLATE_REF (time_point) at line 177
# Visiting node: CursorKind.TYPE_REF (_Clock) at line 177
# Visiting node: CursorKind.TYPE_REF (_Duration) at line 177
# Visiting node: CursorKind.TYPE_ALIAS_DECL (type) at line 178
# Visiting node: CursorKind.NAMESPACE_REF (chrono) at line 178
# Visiting node: CursorKind.TEMPLATE_REF (time_point) at line 178
# Visiting node: CursorKind.TYPE_REF (_Clock) at line 178
# Visiting node: CursorKind.TYPE_REF (_Duration) at line 178
# Visiting node: CursorKind.NAMESPACE (chrono) at line 183
# Visiting node: CursorKind.CLASS_TEMPLATE (__duration_cast_impl) at line 193
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_ToDur) at line 191
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_CF) at line 191
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_CR) at line 191
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_NumIsOne) at line 192
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 192
# Visiting node: CursorKind.TEMPLATE_NON_TYPE_PARAMETER (_DenIsOne) at line 192
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 192
# Visiting node: CursorKind.FUNCTION_TEMPLATE (__cast) at line 197
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Rep) at line 195
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_Period) at line 195
# Visiting node: CursorKind.TYPE_REF (_ToDur) at line 196
# Visiting node: CursorKind.PARM_DECL (__d) at line 197
# Visiting node: CursorKind.TEMPLATE_REF (duration) at line 197
# Visiting node: CursorKind.TYPE_REF (_Rep) at line 197
# Visiting node: CursorKind.TYPE_REF (_Period) at line 197
# Visiting node: CursorKind.COMPOUND_STMT () at line 198
# Visiting node: CursorKind.DECL_STMT () at line 199
# Visiting node: CursorKind.TYPEDEF_DECL (__to_rep) at line 199
# Visiting node: CursorKind.TYPE_REF (_ToDur) at line 199
# Visiting node: CursorKind.RETURN_STMT () at line 200
# Visiting node: CursorKind.CALL_EXPR () at line 200
# Visiting node: CursorKind.TYPE_REF (_ToDur) at line 200
# Visiting node: CursorKind.CXX_STATIC_CAST_EXPR () at line 200
# Visiting node: CursorKind.TYPE_REF (__to_rep) at line 200
# Visiting node: CursorKind.BINARY_OPERATOR () at line 200
# Visiting node: CursorKind.BINARY_OPERATOR () at line 200
# Visiting node: CursorKind.CXX_STATIC_CAST_EXPR () at line 200
# Visiting node: CursorKind.TYPE_REF (_CR) at line 200
# Visiting node: CursorKind.CALL_EXPR () at line 200
# Visiting node: CursorKind.MEMBER_REF_EXPR () at line 200
# Visiting node: CursorKind.DECL_REF_EXPR (__d) at line 200
# Visiting node: CursorKind.CXX_STATIC_CAST_EXPR () at line 201
# Visiting node: CursorKind.TYPE_REF (_CR) at line 201
# Visiting node: CursorKind.DECL_REF_EXPR () at line 201
# Visiting node: CursorKind.TYPE_REF (_CF) at line 201
# Visiting node: CursorKind.CXX_STATIC_CAST_EXPR () at line 202
# Visiting node: CursorKind.TYPE_REF (_CR) at line 202
# Visiting node: CursorKind.DECL_REF_EXPR () at line 202
# Visiting node: CursorKind.TYPE_REF (_CF) at line 202
# Visiting node: CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION (__duration_cast_impl) at line 207
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_ToDur) at line 206
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_CF) at line 206
# Visiting node: CursorKind.TEMPLATE_TYPE_PARAMETER (_CR) at line 206
# Visiting node: CursorKind.TYPE_REF (_ToDur) at line 207
# Visiting node: CursorKind.TYPE_REF (_CF) at line 207
# Visiting node: CursorKind.TYPE_REF (_CR) at line 207
# Visiting node: CursorKind.CXX_BOOL_LITERAL_EXPR () at line 207
# ...
# Visiting node: CursorKind.FIELD_DECL (h1) at line 43
# Visiting node: CursorKind.FIELD_DECL (h2) at line 43
# Visiting node: CursorKind.FIELD_DECL (h3) at line 43
# Visiting node: CursorKind.FIELD_DECL (h4) at line 43
# Visiting node: CursorKind.FIELD_DECL (Nl) at line 44
# Visiting node: CursorKind.FIELD_DECL (Nh) at line 44
# Visiting node: CursorKind.FIELD_DECL (data) at line 45
# Visiting node: CursorKind.INTEGER_LITERAL () at line 45
# Visiting node: CursorKind.FIELD_DECL (num) at line 46
# Visiting node: CursorKind.FUNCTION_DECL (SHA1_Init) at line 49
# Function definition detected: SHA1_Init at line 49
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 49
# Visiting node: CursorKind.PARM_DECL (c) at line 49
# Visiting node: CursorKind.TYPE_REF (SHA_CTX) at line 49
# Visiting node: CursorKind.FUNCTION_DECL (SHA1_Update) at line 50
# Function definition detected: SHA1_Update at line 50
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 50
# Visiting node: CursorKind.PARM_DECL (c) at line 50
# Visiting node: CursorKind.TYPE_REF (SHA_CTX) at line 50
# Visiting node: CursorKind.PARM_DECL (data) at line 50
# Visiting node: CursorKind.PARM_DECL (len) at line 50
# Visiting node: CursorKind.FUNCTION_DECL (SHA1_Final) at line 51
# Function definition detected: SHA1_Final at line 51
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 51
# Visiting node: CursorKind.PARM_DECL (md) at line 51
# Visiting node: CursorKind.PARM_DECL (c) at line 51
# Visiting node: CursorKind.TYPE_REF (SHA_CTX) at line 51
# Visiting node: CursorKind.FUNCTION_DECL (SHA1_Transform) at line 52
# Function definition detected: SHA1_Transform at line 52
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 52
# Visiting node: CursorKind.PARM_DECL (c) at line 52
# Visiting node: CursorKind.TYPE_REF (SHA_CTX) at line 52
# Visiting node: CursorKind.PARM_DECL (data) at line 52
# Visiting node: CursorKind.FUNCTION_DECL (SHA1) at line 55
# Function definition detected: SHA1 at line 55
# Visiting node: CursorKind.PARM_DECL (d) at line 55
# Visiting node: CursorKind.PARM_DECL (n) at line 55
# Visiting node: CursorKind.PARM_DECL (md) at line 55
# Visiting node: CursorKind.STRUCT_DECL (SHA256state_st) at line 62
# Visiting node: CursorKind.FIELD_DECL (h) at line 63
# Visiting node: CursorKind.INTEGER_LITERAL () at line 63
# Visiting node: CursorKind.FIELD_DECL (Nl) at line 64
# Visiting node: CursorKind.FIELD_DECL (Nh) at line 64
# Visiting node: CursorKind.FIELD_DECL (data) at line 65
# Visiting node: CursorKind.INTEGER_LITERAL () at line 65
# Visiting node: CursorKind.FIELD_DECL (num) at line 66
# Visiting node: CursorKind.FIELD_DECL (md_len) at line 66
# Visiting node: CursorKind.TYPEDEF_DECL (SHA256_CTX) at line 67
# Visiting node: CursorKind.STRUCT_DECL (SHA256state_st) at line 62
# Visiting node: CursorKind.FIELD_DECL (h) at line 63
# Visiting node: CursorKind.INTEGER_LITERAL () at line 63
# Visiting node: CursorKind.FIELD_DECL (Nl) at line 64
# Visiting node: CursorKind.FIELD_DECL (Nh) at line 64
# Visiting node: CursorKind.FIELD_DECL (data) at line 65
# Visiting node: CursorKind.INTEGER_LITERAL () at line 65
# Visiting node: CursorKind.FIELD_DECL (num) at line 66
# Visiting node: CursorKind.FIELD_DECL (md_len) at line 66
# Visiting node: CursorKind.FUNCTION_DECL (SHA224_Init) at line 69
# Function definition detected: SHA224_Init at line 69
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 69
# Visiting node: CursorKind.PARM_DECL (c) at line 69
# Visiting node: CursorKind.TYPE_REF (SHA256_CTX) at line 69
# Visiting node: CursorKind.FUNCTION_DECL (SHA224_Update) at line 70
# Function definition detected: SHA224_Update at line 70
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 70
# Visiting node: CursorKind.PARM_DECL (c) at line 70
# Visiting node: CursorKind.TYPE_REF (SHA256_CTX) at line 70
# Visiting node: CursorKind.PARM_DECL (data) at line 71
# Visiting node: CursorKind.PARM_DECL (len) at line 71
# Visiting node: CursorKind.FUNCTION_DECL (SHA224_Final) at line 72
# Function definition detected: SHA224_Final at line 72
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 72
# Visiting node: CursorKind.PARM_DECL (md) at line 72
# Visiting node: CursorKind.PARM_DECL (c) at line 72
# Visiting node: CursorKind.TYPE_REF (SHA256_CTX) at line 72
# Visiting node: CursorKind.FUNCTION_DECL (SHA256_Init) at line 73
# Function definition detected: SHA256_Init at line 73
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 73
# Visiting node: CursorKind.PARM_DECL (c) at line 73
# Visiting node: CursorKind.TYPE_REF (SHA256_CTX) at line 73
# Visiting node: CursorKind.FUNCTION_DECL (SHA256_Update) at line 74
# Function definition detected: SHA256_Update at line 74
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 74
# Visiting node: CursorKind.PARM_DECL (c) at line 74
# Visiting node: CursorKind.TYPE_REF (SHA256_CTX) at line 74
# Visiting node: CursorKind.PARM_DECL (data) at line 75
# Visiting node: CursorKind.PARM_DECL (len) at line 75
# Visiting node: CursorKind.FUNCTION_DECL (SHA256_Final) at line 76
# Function definition detected: SHA256_Final at line 76
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 76
# Visiting node: CursorKind.PARM_DECL (md) at line 76
# Visiting node: CursorKind.PARM_DECL (c) at line 76
# Visiting node: CursorKind.TYPE_REF (SHA256_CTX) at line 76
# Visiting node: CursorKind.FUNCTION_DECL (SHA256_Transform) at line 77
# Function definition detected: SHA256_Transform at line 77
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 77
# Visiting node: CursorKind.PARM_DECL (c) at line 77
# Visiting node: CursorKind.TYPE_REF (SHA256_CTX) at line 77
# Visiting node: CursorKind.PARM_DECL (data) at line 78
# Visiting node: CursorKind.FUNCTION_DECL (SHA224) at line 81
# Function definition detected: SHA224 at line 81
# Visiting node: CursorKind.PARM_DECL (d) at line 81
# Visiting node: CursorKind.PARM_DECL (n) at line 81
# Visiting node: CursorKind.PARM_DECL (md) at line 81
# Visiting node: CursorKind.FUNCTION_DECL (SHA256) at line 82
# Function definition detected: SHA256 at line 82
# Visiting node: CursorKind.PARM_DECL (d) at line 82
# Visiting node: CursorKind.PARM_DECL (n) at line 82
# Visiting node: CursorKind.PARM_DECL (md) at line 82
# Visiting node: CursorKind.STRUCT_DECL (SHA512state_st) at line 109
# Visiting node: CursorKind.FIELD_DECL (h) at line 110
# Visiting node: CursorKind.INTEGER_LITERAL () at line 110
# Visiting node: CursorKind.FIELD_DECL (Nl) at line 111
# Visiting node: CursorKind.FIELD_DECL (Nh) at line 111
# Visiting node: CursorKind.UNION_DECL ((unnamed union at /usr/include/openssl/sha.h:112:5)) at line 112
# Visiting node: CursorKind.FIELD_DECL (d) at line 113
# Visiting node: CursorKind.INTEGER_LITERAL () at line 113
# Visiting node: CursorKind.FIELD_DECL (p) at line 114
# Visiting node: CursorKind.PAREN_EXPR () at line 114
# Visiting node: CursorKind.BINARY_OPERATOR () at line 114
# Visiting node: CursorKind.INTEGER_LITERAL () at line 114
# Visiting node: CursorKind.INTEGER_LITERAL () at line 114
# Visiting node: CursorKind.FIELD_DECL (u) at line 115
# Visiting node: CursorKind.UNION_DECL ((unnamed union at /usr/include/openssl/sha.h:112:5)) at line 112
# Visiting node: CursorKind.FIELD_DECL (d) at line 113
# Visiting node: CursorKind.INTEGER_LITERAL () at line 113
# Visiting node: CursorKind.FIELD_DECL (p) at line 114
# Visiting node: CursorKind.PAREN_EXPR () at line 114
# Visiting node: CursorKind.BINARY_OPERATOR () at line 114
# Visiting node: CursorKind.INTEGER_LITERAL () at line 114
# Visiting node: CursorKind.INTEGER_LITERAL () at line 114
# Visiting node: CursorKind.FIELD_DECL (num) at line 116
# Visiting node: CursorKind.FIELD_DECL (md_len) at line 116
# Visiting node: CursorKind.TYPEDEF_DECL (SHA512_CTX) at line 117
# Visiting node: CursorKind.STRUCT_DECL (SHA512state_st) at line 109
# Visiting node: CursorKind.FIELD_DECL (h) at line 110
# Visiting node: CursorKind.INTEGER_LITERAL () at line 110
# Visiting node: CursorKind.FIELD_DECL (Nl) at line 111
# Visiting node: CursorKind.FIELD_DECL (Nh) at line 111
# Visiting node: CursorKind.UNION_DECL ((unnamed union at /usr/include/openssl/sha.h:112:5)) at line 112
# Visiting node: CursorKind.FIELD_DECL (d) at line 113
# Visiting node: CursorKind.INTEGER_LITERAL () at line 113
# Visiting node: CursorKind.FIELD_DECL (p) at line 114
# Visiting node: CursorKind.PAREN_EXPR () at line 114
# Visiting node: CursorKind.BINARY_OPERATOR () at line 114
# Visiting node: CursorKind.INTEGER_LITERAL () at line 114
# Visiting node: CursorKind.INTEGER_LITERAL () at line 114
# Visiting node: CursorKind.FIELD_DECL (u) at line 115
# Visiting node: CursorKind.UNION_DECL ((unnamed union at /usr/include/openssl/sha.h:112:5)) at line 112
# Visiting node: CursorKind.FIELD_DECL (d) at line 113
# Visiting node: CursorKind.INTEGER_LITERAL () at line 113
# Visiting node: CursorKind.FIELD_DECL (p) at line 114
# Visiting node: CursorKind.PAREN_EXPR () at line 114
# Visiting node: CursorKind.BINARY_OPERATOR () at line 114
# Visiting node: CursorKind.INTEGER_LITERAL () at line 114
# Visiting node: CursorKind.INTEGER_LITERAL () at line 114
# Visiting node: CursorKind.FIELD_DECL (num) at line 116
# Visiting node: CursorKind.FIELD_DECL (md_len) at line 116
# Visiting node: CursorKind.FUNCTION_DECL (SHA384_Init) at line 119
# Function definition detected: SHA384_Init at line 119
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 119
# Visiting node: CursorKind.PARM_DECL (c) at line 119
# Visiting node: CursorKind.TYPE_REF (SHA512_CTX) at line 119
# Visiting node: CursorKind.FUNCTION_DECL (SHA384_Update) at line 120
# Function definition detected: SHA384_Update at line 120
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 120
# Visiting node: CursorKind.PARM_DECL (c) at line 120
# Visiting node: CursorKind.TYPE_REF (SHA512_CTX) at line 120
# Visiting node: CursorKind.PARM_DECL (data) at line 121
# Visiting node: CursorKind.PARM_DECL (len) at line 121
# Visiting node: CursorKind.FUNCTION_DECL (SHA384_Final) at line 122
# Function definition detected: SHA384_Final at line 122
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 122
# Visiting node: CursorKind.PARM_DECL (md) at line 122
# Visiting node: CursorKind.PARM_DECL (c) at line 122
# Visiting node: CursorKind.TYPE_REF (SHA512_CTX) at line 122
# Visiting node: CursorKind.FUNCTION_DECL (SHA512_Init) at line 123
# Function definition detected: SHA512_Init at line 123
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 123
# Visiting node: CursorKind.PARM_DECL (c) at line 123
# Visiting node: CursorKind.TYPE_REF (SHA512_CTX) at line 123
# Visiting node: CursorKind.FUNCTION_DECL (SHA512_Update) at line 124
# Function definition detected: SHA512_Update at line 124
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 124
# Visiting node: CursorKind.PARM_DECL (c) at line 124
# Visiting node: CursorKind.TYPE_REF (SHA512_CTX) at line 124
# Visiting node: CursorKind.PARM_DECL (data) at line 125
# Visiting node: CursorKind.PARM_DECL (len) at line 125
# Visiting node: CursorKind.FUNCTION_DECL (SHA512_Final) at line 126
# Function definition detected: SHA512_Final at line 126
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 126
# Visiting node: CursorKind.PARM_DECL (md) at line 126
# Visiting node: CursorKind.PARM_DECL (c) at line 126
# Visiting node: CursorKind.TYPE_REF (SHA512_CTX) at line 126
# Visiting node: CursorKind.FUNCTION_DECL (SHA512_Transform) at line 127
# Function definition detected: SHA512_Transform at line 127
# Visiting node: CursorKind.UNEXPOSED_ATTR () at line 127
# Visiting node: CursorKind.PARM_DECL (c) at line 127
# Visiting node: CursorKind.TYPE_REF (SHA512_CTX) at line 127
# Visiting node: CursorKind.PARM_DECL (data) at line 128
# Visiting node: CursorKind.FUNCTION_DECL (SHA384) at line 131
# Function definition detected: SHA384 at line 131
# Visiting node: CursorKind.PARM_DECL (d) at line 131
# Visiting node: CursorKind.PARM_DECL (n) at line 131
# Visiting node: CursorKind.PARM_DECL (md) at line 131
# Visiting node: CursorKind.FUNCTION_DECL (SHA512) at line 132
# Function definition detected: SHA512 at line 132
# Visiting node: CursorKind.PARM_DECL (d) at line 132
# Visiting node: CursorKind.PARM_DECL (n) at line 132
# Visiting node: CursorKind.PARM_DECL (md) at line 132
# Visiting node: CursorKind.VAR_DECL (shared_data) at line 8
# Visiting node: CursorKind.INTEGER_LITERAL () at line 8
# Visiting node: CursorKind.VAR_DECL (mtx) at line 9
# Visiting node: CursorKind.NAMESPACE_REF (std) at line 9
# Visiting node: CursorKind.TYPE_REF (class std::mutex) at line 9
# Visiting node: CursorKind.CALL_EXPR (mutex) at line 9
# Locking mechanism detected: mutex at line 9
# Visiting node: CursorKind.FUNCTION_DECL (unsafe_thread_func) at line 11
# Function definition detected: unsafe_thread_func at line 11
# Visiting node: CursorKind.COMPOUND_STMT () at line 11
# Visiting node: CursorKind.UNARY_OPERATOR () at line 12
# Visiting node: CursorKind.DECL_REF_EXPR (shared_data) at line 12
# Visiting node: CursorKind.FUNCTION_DECL (safe_thread_func) at line 15
# Function definition detected: safe_thread_func at line 15
# Visiting node: CursorKind.COMPOUND_STMT () at line 15
# Visiting node: CursorKind.DECL_STMT () at line 16
# Visiting node: CursorKind.VAR_DECL (guard) at line 16
# Visiting node: CursorKind.NAMESPACE_REF (std) at line 16
# Visiting node: CursorKind.TEMPLATE_REF (lock_guard) at line 16
# Visiting node: CursorKind.NAMESPACE_REF (std) at line 16
# Visiting node: CursorKind.TYPE_REF (class std::mutex) at line 16
# Visiting node: CursorKind.UNARY_OPERATOR () at line 17
# Visiting node: CursorKind.DECL_REF_EXPR (shared_data) at line 17
# Visiting node: CursorKind.FUNCTION_DECL (hash_function) at line 20
# Function definition detected: hash_function at line 20
# Visiting node: CursorKind.COMPOUND_STMT () at line 20
# Visiting node: CursorKind.DECL_STMT () at line 21
# Visiting node: CursorKind.VAR_DECL (input) at line 21
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 21
# Visiting node: CursorKind.STRING_LITERAL ("data") at line 21
# Visiting node: CursorKind.DECL_STMT () at line 22
# Visiting node: CursorKind.VAR_DECL (output) at line 22
# Visiting node: CursorKind.INTEGER_LITERAL () at line 22
# Visiting node: CursorKind.CALL_EXPR () at line 23
# Visiting node: CursorKind.DECL_REF_EXPR () at line 23
# Visiting node: CursorKind.OVERLOADED_DECL_REF (MD5) at line 23
# Visiting node: CursorKind.CSTYLE_CAST_EXPR () at line 23
# Visiting node: CursorKind.UNEXPOSED_EXPR (input) at line 23
# Visiting node: CursorKind.DECL_REF_EXPR (input) at line 23
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 23
# Visiting node: CursorKind.DECL_REF_EXPR () at line 23
# Visiting node: CursorKind.OVERLOADED_DECL_REF (strlen) at line 23
# Visiting node: CursorKind.DECL_REF_EXPR (input) at line 23
# Visiting node: CursorKind.DECL_REF_EXPR (output) at line 23
# Visiting node: CursorKind.FUNCTION_DECL (main) at line 26
# Function definition detected: main at line 26
# Visiting node: CursorKind.COMPOUND_STMT () at line 26
# Visiting node: CursorKind.DECL_STMT () at line 27
# Visiting node: CursorKind.VAR_DECL (t1) at line 27
# Visiting node: CursorKind.NAMESPACE_REF (std) at line 27
# Visiting node: CursorKind.TYPE_REF (class std::thread) at line 27
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 27
# Visiting node: CursorKind.DECL_REF_EXPR (unsafe_thread_func) at line 27
# Visiting node: CursorKind.DECL_STMT () at line 28
# Visiting node: CursorKind.VAR_DECL (t2) at line 28
# Visiting node: CursorKind.NAMESPACE_REF (std) at line 28
# Visiting node: CursorKind.TYPE_REF (class std::thread) at line 28
# Visiting node: CursorKind.UNEXPOSED_EXPR () at line 28
# Visiting node: CursorKind.DECL_REF_EXPR (unsafe_thread_func) at line 28
# Visiting node: CursorKind.CALL_EXPR (join) at line 30
# Visiting node: CursorKind.MEMBER_REF_EXPR (join) at line 30
# Visiting node: CursorKind.DECL_REF_EXPR (t1) at line 30
# Visiting node: CursorKind.CALL_EXPR (join) at line 31
# Visiting node: CursorKind.MEMBER_REF_EXPR (join) at line 31
# Visiting node: CursorKind.DECL_REF_EXPR (t2) at line 31
# Visiting node: CursorKind.CALL_EXPR (hash_function) at line 33
# Visiting node: CursorKind.UNEXPOSED_EXPR (hash_function) at line 33
# Visiting node: CursorKind.DECL_REF_EXPR (hash_function) at line 33
# Visiting node: CursorKind.RETURN_STMT () at line 35
# Visiting node: CursorKind.INTEGER_LITERAL () at line 35
#
# No vulnerabilities detected.

# %%
import clang.cindex
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/sample.cpp'

# Set up Clang library if needed (usually required for non-standard setups)
# clang.cindex.Config.set_library_file("/path/to/libclang.so")

class CppVulnerabilityAnalyzer:
    def __init__(self, file_path):
        self.file_path = file_path
        self.index = clang.cindex.Index.create()
        self.vulnerabilities = []

    def analyze(self):
        translation_unit = self.index.parse(self.file_path)
        self.traverse_ast(translation_unit.cursor)

    def traverse_ast(self, node):
        # Detect Race Condition
        if node.kind == clang.cindex.CursorKind.CALL_EXPR:
            # Example: Detecting unsafe thread-related functions like pthread_create, without synchronization
            if node.spelling in ["pthread_create", "std::thread"]:
                self.check_race_condition(node)

        # Detect Insufficient Cryptographic Protection
        if node.kind == clang.cindex.CursorKind.CALL_EXPR:
            if node.spelling in ["MD5", "SHA1", "DES"]:
                self.vulnerabilities.append(
                    f"Weak cryptographic algorithm ({node.spelling}) detected at line {node.location.line}"
                )

        # Recursively traverse the AST
        for child in node.get_children():
            self.traverse_ast(child)

    def check_race_condition(self, node):
        """
        Check if shared data is accessed without synchronization.
        """
        parent_function = self.find_parent_function(node)
        if parent_function:
            shared_resources = self.detect_shared_resources(parent_function)
            for resource in shared_resources:
                if not self.is_synchronized(resource, parent_function):
                    self.vulnerabilities.append(
                        f"Potential race condition detected for resource '{resource}' at line {node.location.line}"
                    )

    def find_parent_function(self, node):
        """
        Find the parent function containing the node.
        """
        while node is not None and node.kind != clang.cindex.CursorKind.FUNCTION_DECL:
            node = node.semantic_parent
        return node

    def detect_shared_resources(self, function_node):
        """
        Detect variables that may be shared across threads.
        """
        shared_resources = []
        for child in function_node.get_children():
            if child.kind == clang.cindex.CursorKind.VAR_DECL and "shared" in child.spelling.lower():
                shared_resources.append(child.spelling)
        return shared_resources

    def is_synchronized(self, resource, function_node):
        """
        Check if access to the shared resource is synchronized.
        """
        for child in function_node.get_children():
            if child.kind == clang.cindex.CursorKind.CALL_EXPR:
                # Check for synchronization primitives like mutexes
                if "lock" in child.spelling or "mutex" in child.spelling:
                    return True
        return False

    def report(self):
        if self.vulnerabilities:
            print("Detected Vulnerabilities:")
            for vulnerability in self.vulnerabilities:
                print(vulnerability)
        else:
            print("No vulnerabilities detected.")

if __name__ == "__main__":
    analyzer = CppVulnerabilityAnalyzer(file_path)
    analyzer.analyze()
    analyzer.report()
# Out:
# Mounted at /content/drive
# No vulnerabilities detected.

# %%
import re

# Sample C++ code
cpp_code = """
#include <iostream>
#include <thread>
#include <mutex>
#include <openssl/md5.h>
#include <openssl/sha.h>

// Shared resource with potential race condition
int shared_data = 0;
std::mutex mtx;

void unsafe_thread_func() {
    shared_data++;  // Vulnerable: access without locking
}

void safe_thread_func() {
    std::lock_guard<std::mutex> guard(mtx);
    shared_data++;  // Safe: access with locking
}

void hash_function() {
    const char* input = "data";
    unsigned char output[MD5_DIGEST_LENGTH];
    MD5((unsigned char*)input, strlen(input), output);  // Vulnerable: Using MD5
}

int main() {
    std::thread t1(unsafe_thread_func);
    std::thread t2(unsafe_thread_func);

    t1.join();
    t2.join();

    hash_function();

    return 0;
}
"""

# Regex patterns for detecting vulnerabilities
regex_patterns = {
    "race_condition_threads": r"\bstd::thread\b\s*\w+\s*\(",
    "mutex_lock": r"\bstd::lock_guard<\s*std::mutex\s*>\b|\bstd::mutex\b",
    "weak_crypto": r"\b(MD5|SHA1|DES)\b\s*\(",
}

def detect_vulnerabilities(code):
    vulnerabilities = []

    # Detect race conditions by finding thread usages without mutex locks
    thread_matches = re.findall(regex_patterns["race_condition_threads"], code)
    mutex_matches = re.findall(regex_patterns["mutex_lock"], code)

    if thread_matches:
        if not mutex_matches:
            vulnerabilities.append(f"Potential race condition detected: Threads created without mutex lock.")
        else:
            thread_lines = [match.start() for match in re.finditer(regex_patterns["race_condition_threads"], code)]
            mutex_lines = [match.start() for match in re.finditer(regex_patterns["mutex_lock"], code)]

            # Simple heuristic: if thread creation is detected without a lock in the same function scope
            for thread_pos in thread_lines:
                if not any(mutex_pos < thread_pos for mutex_pos in mutex_lines):
                    vulnerabilities.append(f"Potential race condition detected at position {thread_pos}: Thread without mutex lock.")

    # Detect weak cryptographic algorithms
    weak_crypto_matches = re.finditer(regex_patterns["weak_crypto"], code)
    for match in weak_crypto_matches:
        vulnerabilities.append(f"Weak cryptographic algorithm ({match.group(1)}) detected at position {match.start()}")

    return vulnerabilities

# Analyze the sample code
vulnerabilities = detect_vulnerabilities(cpp_code)

# Report the findings
if vulnerabilities:
    print("Detected Vulnerabilities:")
    for vulnerability in vulnerabilities:
        print(vulnerability)
else:
    print("No vulnerabilities detected.")
# Out:
# Detected Vulnerabilities:
# Weak cryptographic algorithm (MD5) detected at position 509

# %%
import clang.cindex

# Set up Clang library if needed (usually required for non-standard setups)
# clang.cindex.Config.set_library_file("/path/to/libclang.so")

from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/sample.cpp'

class CppVulnerabilityAnalyzer:
    def __init__(self, file_path):
        self.file_path = file_path
        self.index = clang.cindex.Index.create()
        self.vulnerabilities = []

    def analyze(self):
        translation_unit = self.index.parse(self.file_path)
        self.traverse_ast(translation_unit.cursor)

    def traverse_ast(self, node):
        # Detect Race Condition
        if node.kind == clang.cindex.CursorKind.CALL_EXPR:
            # Example: Detecting unsafe thread-related functions like pthread_create, without synchronization
            if node.spelling in ["pthread_create", "std::thread"]:
                self.check_race_condition(node)

        # Detect Insufficient Cryptographic Protection
        if node.kind == clang.cindex.CursorKind.CALL_EXPR:
            if node.spelling in ["MD5", "SHA1", "DES"]:
                self.vulnerabilities.append(
                    f"Weak cryptographic algorithm ({node.spelling}) detected at line {node.location.line}"
                )

        # Recursively traverse the AST
        for child in node.get_children():
            self.traverse_ast(child)

    def check_race_condition(self, node):
        """
        Check if shared data is accessed without synchronization.
        """
        parent_function = self.find_parent_function(node)
        if parent_function:
            shared_resources = self.detect_shared_resources(parent_function)
            for resource in shared_resources:
                if not self.is_synchronized(resource, parent_function):
                    self.vulnerabilities.append(
                        f"Potential race condition detected for resource '{resource}' at line {node.location.line}"
                    )

    def find_parent_function(self, node):
        """
        Find the parent function containing the node.
        """
        while node is not None and node.kind != clang.cindex.CursorKind.FUNCTION_DECL:
            node = node.semantic_parent
        return node

    def detect_shared_resources(self, function_node):
        """
        Detect variables that may be shared across threads.
        """
        shared_resources = []
        for child in function_node.get_children():
            if child.kind == clang.cindex.CursorKind.VAR_DECL and "shared" in child.spelling.lower():
                shared_resources.append(child.spelling)
        return shared_resources

    def is_synchronized(self, resource, function_node):
        """
        Check if access to the shared resource is synchronized.
        """
        for child in function_node.get_children():
            if child.kind == clang.cindex.CursorKind.CALL_EXPR:
                # Check for synchronization primitives like mutexes
                if "lock" in child.spelling or "mutex" in child.spelling:
                    return True
        return False

    def report(self):
        if self.vulnerabilities:
            print("Detected Vulnerabilities:")
            for vulnerability in self.vulnerabilities:
                print(vulnerability)
        else:
            print("No vulnerabilities detected.")

if __name__ == "__main__":
    analyzer = CppVulnerabilityAnalyzer(file_path)
    analyzer.analyze()
    analyzer.report()
# Out:
# Mounted at /content/drive
# No vulnerabilities detected.

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Step 1: Prepare the Dataset
# Example C++ code snippets with labels (1 = Vulnerable, 0 = Safe)
code_snippets = [
    # Vulnerable code snippets (Race conditions)
    "std::thread t1(unsafe_thread_func); std::thread t2(unsafe_thread_func); t1.join(); t2.join();",  # Vulnerable
    "shared_data++;",  # Vulnerable: access without locking
    # Safe code snippets (Proper synchronization)
    "std::lock_guard<std::mutex> guard(mtx); shared_data++;",  # Safe
    "std::mutex mtx; std::unique_lock<std::mutex> lock(mtx); shared_data++;",  # Safe
    # Vulnerable code snippets (Weak Cryptographic Functions)
    "unsigned char output[MD5_DIGEST_LENGTH]; MD5((unsigned char*)input, strlen(input), output);",  # Vulnerable: MD5
    "unsigned char hash[SHA_DIGEST_LENGTH]; SHA1(input, strlen(input), hash);",  # Vulnerable: SHA1
    # Safe code snippets (Secure Cryptographic Functions)
    "unsigned char hash[SHA256_DIGEST_LENGTH]; SHA256(input, strlen(input), hash);",  # Safe
    "unsigned char hash[SHA512_DIGEST_LENGTH]; SHA512(input, strlen(input), hash);",  # Safe
]

# Corresponding labels (1 = Vulnerable, 0 = Safe)
labels = [1, 1, 0, 0, 1, 1, 0, 0]

# Step 2: Feature Extraction using TF-IDF
vectorizer = TfidfVectorizer(token_pattern=r'\b\w+\b', max_features=100)
X = vectorizer.fit_transform(code_snippets)
y = np.array(labels)

# Step 3: Train/Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Step 4: Train the Random Forest Classifier
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Step 5: Evaluate the Model
y_pred = model.predict(X_test)
print("Classification Report:\n", classification_report(y_test, y_pred))

# Output some test predictions
test_snippets = [
    "std::thread t1(unsafe_thread_func); t1.join();",  # Expected Vulnerable
    "std::lock_guard<std::mutex> guard(mtx); shared_data++;",  # Expected Safe
    "MD5((unsigned char*)input, strlen(input), output);",  # Expected Vulnerable
]

# Transform the test snippets
X_test_snippets = vectorizer.transform(test_snippets)
test_predictions = model.predict(X_test_snippets)

print("\nTest Predictions:")
for snippet, prediction in zip(test_snippets, test_predictions):
    print(f"Snippet: {snippet[:50]}... Prediction: {'Vulnerable' if prediction == 1 else 'Safe'}")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       0.0
#            1       0.00      0.00      0.00       2.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
#
#
# Test Predictions:
# Snippet: std::thread t1(unsafe_thread_func); t1.join();... Prediction: Vulnerable
# Snippet: std::lock_guard<std::mutex> guard(mtx); shared_dat... Prediction: Safe
# Snippet: MD5((unsigned char*)input, strlen(input), output);... Prediction: Safe
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
from google.colab import drive

# Step 1: Mount Google Drive to access files
drive.mount('/content/drive')

# Step 2: Load code snippets from Google Drive
file_path = '/content/drive/MyDrive/sample.cpp'  # Update with your file path

# Read the content of the file
with open(file_path, 'r') as file:
    code_snippet = file.read()

# Step 3: Load the pre-trained CodeBERT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("microsoft/codebert-base")
model = AutoModelForSequenceClassification.from_pretrained("microsoft/codebert-base", num_labels=2)

# Step 4: Tokenize the input code snippet
inputs = tokenizer(code_snippet, return_tensors="pt", padding=True, truncation=True, max_length=512)

# Step 5: Perform inference to classify the code snippet
with torch.no_grad():  # No need for gradient computation during inference
    outputs = model(**inputs)
    predictions = torch.argmax(outputs.logits, dim=-1)

# Step 6: Output the classification result
vulnerability = "Vulnerable" if predictions[0].item() == 1 else "Safe"
print(f"Code is classified as: {vulnerability}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/498 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at microsoft/codebert-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Code is classified as: Vulnerable

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import re
from google.colab import drive

# Step 1: Mount Google Drive to access files
drive.mount('/content/drive')

# Step 2: Load code snippets from Google Drive
file_path = '/content/drive/MyDrive/sample.cpp'  # Update with your file path

# Read the content of the file
with open(file_path, 'r') as file:
    code_snippet = file.read()

# Step 3: Load the pre-trained CodeBERT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("microsoft/codebert-base")
model = AutoModelForSequenceClassification.from_pretrained("microsoft/codebert-base", num_labels=2)

# Step 4: Tokenize the input code snippet
inputs = tokenizer(code_snippet, return_tensors="pt", padding=True, truncation=True, max_length=512)

# Step 5: Perform inference to classify the code snippet
with torch.no_grad():  # No need for gradient computation during inference
    outputs = model(**inputs)
    predictions = torch.argmax(outputs.logits, dim=-1)

# Determine if the code is vulnerable or safe based on CodeBERT
codebert_vulnerability = "Vulnerable" if predictions[0].item() == 1 else "Safe"
print(f"CodeBERT classified code as: {codebert_vulnerability}")

# Step 6: Improved Rule-Based Detection for Explaining Vulnerabilities
def explain_vulnerability(code_snippet):
    explanations = []

    # Example 1: Check for weak cryptographic algorithms (e.g., MD5)
    if re.search(r'\bMD5\b', code_snippet):
        explanations.append("Weak Cryptographic Algorithm: The code uses MD5 for hashing, which is considered insecure due to vulnerabilities to collision attacks. Consider using a more secure algorithm like SHA-256.")

    # Example 2: Check for potential race conditions (e.g., shared resources without locks)
    # Look for shared variable declarations and usage
    shared_var_pattern = re.compile(r'int\s+(\w+)\s*=\s*\d+;')  # Detect shared integer variables
    thread_creation_pattern = re.compile(r'\bstd::thread\b\s*\w*\s*\(\s*(\w+)\s*\)')  # Detect thread creation
    mutex_pattern = re.compile(r'\bstd::(lock_guard|mutex|unique_lock)\b')  # Detect mutex usage

    shared_vars = shared_var_pattern.findall(code_snippet)
    thread_usages = thread_creation_pattern.findall(code_snippet)

    # If there are shared variables and threads created, but no mutex is found, it's a potential race condition
    if shared_vars and thread_usages and not mutex_pattern.search(code_snippet):
        for var in shared_vars:
            explanations.append(f"Potential Race Condition: The shared variable '{var}' is accessed from multiple threads without proper synchronization (like std::lock_guard or std::mutex). This can lead to unpredictable behavior.")

    # More checks can be added here for different types of vulnerabilities

    # Return explanations if any are found
    if explanations:
        return "\n".join(explanations)
    else:
        return None

# Step 7: Hybrid approach - Check both CodeBERT's output and regex patterns
if codebert_vulnerability == "Vulnerable":
    explanation = explain_vulnerability(code_snippet)
    if explanation:
        print("\nExplanation of Vulnerability:")
        print(explanation)
    else:
        print("\nCodeBERT indicated vulnerability, but no specific pattern was matched.")
else:
    explanation = explain_vulnerability(code_snippet)
    if explanation:
        print(f"\nThe code is safe according to CodeBERT but has potential issues:\n{explanation}")
    else:
        print("Code is classified as safe.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at microsoft/codebert-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# CodeBERT classified code as: Safe
#
# The code is safe according to CodeBERT but has potential issues:
# Weak Cryptographic Algorithm: The code uses MD5 for hashing, which is considered insecure due to vulnerabilities to collision attacks. Consider using a more secure algorithm like SHA-256.

# %%
import os
import clang.cindex

# Define insecure methods and their descriptions
INSECURE_METHODS = {
    'MD5': {
        'description': 'MD5 is a weak hashing algorithm that is vulnerable to collision attacks.',
        'suggestion': 'Use SHA-256 or better for hashing.'
    },
    'SHA1': {
        'description': 'SHA-1 is no longer considered secure due to vulnerability to collision attacks.',
        'suggestion': 'Use SHA-256 or better for hashing.'
    },
    'SHA-1': {
        'description': 'SHA-1 is no longer considered secure due to vulnerability to collision attacks.',
        'suggestion': 'Use SHA-256 or better for hashing.'
    }
}

def find_insecure_methods(node):
    """Recursively traverse the AST and find insecure methods."""
    if node.kind == clang.cindex.CursorKind.CALL_EXPR:
        method_info = INSECURE_METHODS.get(node.spelling)
        if method_info:
            print(f"Insecure method found: {node.spelling} at {node.location}")
            print(f"Description: {method_info['description']}")
            print(f"Suggestion: {method_info['suggestion']}")
            print('-' * 50)  # Separator for readability
    for child in node.get_children():
        find_insecure_methods(child)

def parse_file(file_path):
    """Parse the given C++ file and analyze it."""
    try:
        print(f"Parsing file: {file_path}")  # Debugging line
        index = clang.cindex.Index.create()
        translation_unit = index.parse(file_path)
        find_insecure_methods(translation_unit.cursor)
    except Exception as e:
        print(f"Error parsing {file_path}: {e}")

def parse_directory(directory):
    """Walk through the directory and analyze .cpp and .h files."""
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.cpp') or file.endswith('.h'):
                print(f"Scanning {file}...")
                parse_file(os.path.join(root, file))

# '/content/drive/MyDrive/sample.cpp'
directory_to_scan = '/content/drive/MyDrive/test'
parse_directory(directory_to_scan)
# Out:
# Scanning sample.cpp...
# Parsing file: /content/drive/MyDrive/test/sample.cpp

# %% [markdown]
# ## **Text Search for Insecure Methods**
# This method won't parse the C++ syntax, but it can effectively find insecure function calls in a straightforward way

# %%
import os

# Define insecure methods and their descriptions
INSECURE_METHODS = {
    'MD5': {
        'description': 'MD5 is a weak hashing algorithm that is vulnerable to collision attacks.',
        'suggestion': 'Use SHA-256 or better for hashing.'
    },
    'SHA1': {
        'description': 'SHA-1 is no longer considered secure due to vulnerability to collision attacks.',
        'suggestion': 'Use SHA-256 or better for hashing.'
    },
    'SHA-1': {
        'description': 'SHA-1 is no longer considered secure due to vulnerability to collision attacks.',
        'suggestion': 'Use SHA-256 or better for hashing.'
    }
}

def find_insecure_methods(file_path):
    """Search for insecure methods in the given file."""
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
            for method, info in INSECURE_METHODS.items():
                if method in content:
                    print(f"Insecure method found: {method} in {file_path}")
                    print(f"Description: {info['description']}")
                    print(f"Suggestion: {info['suggestion']}")
                    print('-' * 50)  # Separator for readability
    except Exception as e:
        print(f"Error reading {file_path}: {e}")

def parse_directory(directory):
    """Walk through the directory and analyze .cpp and .h files."""
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.cpp') or file.endswith('.h'):
                print(f"Scanning {file}...")
                find_insecure_methods(os.path.join(root, file))


directory_to_scan = '/content/drive/MyDrive/test'
parse_directory(directory_to_scan)
# Out:
# Scanning sample.cpp...
# Insecure method found: MD5 in /content/drive/MyDrive/test/sample.cpp
# Description: MD5 is a weak hashing algorithm that is vulnerable to collision attacks.
# Suggestion: Use SHA-256 or better for hashing.
# --------------------------------------------------
# Insecure method found: SHA1 in /content/drive/MyDrive/test/sample.cpp
# Description: SHA-1 is no longer considered secure due to vulnerability to collision attacks.
# Suggestion: Use SHA-256 or better for hashing.
# --------------------------------------------------
# Insecure method found: SHA-1 in /content/drive/MyDrive/test/sample.cpp
# Description: SHA-1 is no longer considered secure due to vulnerability to collision attacks.
# Suggestion: Use SHA-256 or better for hashing.
# --------------------------------------------------

# %%
# !apt-get install -y cppcheck
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libtinyxml2-9 libz3-4 python3-pygments
# Suggested packages:
#   cppcheck-gui clang-tidy python-pygments-doc ttf-bitstream-vera
# The following NEW packages will be installed:
#   cppcheck libtinyxml2-9 libz3-4 python3-pygments
# 0 upgraded, 4 newly installed, 0 to remove and 49 not upgraded.
# Need to get 8,564 kB of archives.
# After this operation, 29.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtinyxml2-9 amd64 9.0.0+dfsg-3 [32.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libz3-4 amd64 4.8.12-1 [5,766 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-pygments all 2.11.2+dfsg-2 [750 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 cppcheck amd64 2.7-1 [2,016 kB]
# Fetched 8,564 kB in 3s (2,930 kB/s)
# Selecting previously unselected package libtinyxml2-9:amd64.
# (Reading database ... 123621 files and directories currently installed.)
# Preparing to unpack .../libtinyxml2-9_9.0.0+dfsg-3_amd64.deb ...
# Unpacking libtinyxml2-9:amd64 (9.0.0+dfsg-3) ...
# Selecting previously unselected package libz3-4:amd64.
# Preparing to unpack .../libz3-4_4.8.12-1_amd64.deb ...
# Unpacking libz3-4:amd64 (4.8.12-1) ...
# Selecting previously unselected package python3-pygments.
# Preparing to unpack .../python3-pygments_2.11.2+dfsg-2_all.deb ...
# Unpacking python3-pygments (2.11.2+dfsg-2) ...
# Selecting previously unselected package cppcheck.
# Preparing to unpack .../cppcheck_2.7-1_amd64.deb ...
# Unpacking cppcheck (2.7-1) ...
# Setting up python3-pygments (2.11.2+dfsg-2) ...
# Setting up libz3-4:amd64 (4.8.12-1) ...
# Setting up libtinyxml2-9:amd64 (9.0.0+dfsg-3) ...
# Setting up cppcheck (2.7-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link

# %%
import os
if os.path.exists(directory_to_scan):
    print("Directory contents:", os.listdir(directory_to_scan))
else:
    print("Directory does not exist.")

# Run Cppcheck and output to a text file
output_file = 'cppcheck_report.txt'
# !cppcheck --enable=all {directory_to_scan} --output-file={output_file}

# Read and print the report if it exists
if os.path.exists(output_file):
    with open(output_file, 'r') as f:
        report = f.read()
    print(report)
else:
    print("Cppcheck report was not generated.")
# Out:
# Directory contents: ['sample.cpp']
# Checking /content/drive/MyDrive/test/sample.cpp ...
# /content/drive/MyDrive/test/sample.cpp:16:0: style: The function 'safe_thread_func' is never used. [unusedFunction]
#
# ^
# nofile:0:0: information: Cppcheck cannot find all the include files (use --check-config for details) [missingIncludeSystem]

# %%
import os
import re

def find_insecure_crypto(directory):
    # Regex pattern to match MD5 and SHA-1 function calls
    insecure_pattern = re.compile(r'\b(MD5|SHA1)\b', re.IGNORECASE)

    vulnerabilities = []

    # Walk through the directory
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.cpp'):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    code = f.read()

                    # Search for insecure cryptographic methods
                    matches = insecure_pattern.findall(code)
                    if matches:
                        for match in matches:
                            vulnerability_info = {
                                "file": file_path,
                                "function": match,
                                "explanation": (
                                    f"{match} is an insecure cryptographic function. "
                                    "Both MD5 and SHA-1 are considered weak due to vulnerabilities "
                                    "that allow for collision attacks, where two different inputs "
                                    "produce the same hash. This can lead to security issues such as "
                                    "forgery of digital signatures and data integrity violations."
                                ),
                                "suggestion": (
                                    "Consider using stronger hashing algorithms like SHA-256 or SHA-3. "
                                    "Additionally, review the cryptographic standards for your application "
                                    "to ensure compliance with modern security practices."
                                )
                            }
                            vulnerabilities.append(vulnerability_info)

    return vulnerabilities

# Example usage
directory_to_scan = '/content/drive/MyDrive/test'
results = find_insecure_crypto(directory_to_scan)

if results:
    for result in results:
        print(f"File: {result['file']}")
        print(f"Function: {result['function']}")
        print(f"Explanation: {result['explanation']}")
        print(f"Suggestion: {result['suggestion']}")
        print("-" * 80)  # Separator for better readability
else:
    print("No vulnerabilities found.")
# Out:
# File: /content/drive/MyDrive/test/sample.cpp
# Function: md5
# Explanation: md5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: SHA1
# Explanation: SHA1 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------

# %%
import os
import re

def find_insecure_crypto(directory):
    # Regex pattern to match MD5 and SHA-1 function calls
    insecure_pattern = re.compile(r'\b(MD5|SHA1)\b', re.IGNORECASE)

    vulnerabilities = []

    # Walk through the directory
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.cpp'):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    code = f.read()

                    # Search for insecure cryptographic methods
                    matches = insecure_pattern.findall(code)
                    if matches:
                        for match in matches:
                            vulnerability_info = {
                                "file": file_path,
                                "function": match,
                                "explanation": (
                                    f"{match} is an insecure cryptographic function. "
                                    "Both MD5 and SHA-1 are considered weak due to vulnerabilities "
                                    "that allow for collision attacks, where two different inputs "
                                    "produce the same hash. This can lead to security issues such as "
                                    "forgery of digital signatures and data integrity violations."
                                ),
                                "suggestion": (
                                    "Consider using stronger hashing algorithms like SHA-256 or SHA-3. "
                                    "Additionally, review the cryptographic standards for your application "
                                    "to ensure compliance with modern security practices."
                                )
                            }
                            vulnerabilities.append(vulnerability_info)

    return vulnerabilities

# Example usage
directory_to_scan = '/content/drive/MyDrive/test'
results = find_insecure_crypto(directory_to_scan)

if results:
    for result in results:
        print(f"File: {result['file']}")
        print(f"Function: {result['function']}")
        print(f"Explanation: {result['explanation']}")
        print(f"Suggestion: {result['suggestion']}")
        print("-" * 80)  # Separator for better readability
else:
    print("No vulnerabilities found.")
# Out:
# File: /content/drive/MyDrive/test/sample.cpp
# Function: md5
# Explanation: md5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: SHA1
# Explanation: SHA1 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------

# %%
import os
import re

def find_insecure_crypto(directory):
    # Regex pattern to match MD5 and SHA-1 function calls (including EVP_ prefixed ones)
    insecure_pattern = re.compile(r'\b(EVP_(md5|sha1)|MD5|SHA1)\b', re.IGNORECASE)

    vulnerabilities = []

    # Walk through the directory
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.cpp'):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    code = f.read()

                    # Search for insecure cryptographic methods
                    matches = insecure_pattern.findall(code)
                    if matches:
                        for match in matches:
                            # Extract the function name
                            function_name = match[0]  # The full match (e.g., EVP_md5)
                            vulnerability_info = {
                                "file": file_path,
                                "function": function_name,
                                "explanation": (
                                    f"{function_name} is an insecure cryptographic function. "
                                    "Both MD5 and SHA-1 are considered weak due to vulnerabilities "
                                    "that allow for collision attacks, where two different inputs "
                                    "produce the same hash. This can lead to security issues such as "
                                    "forgery of digital signatures and data integrity violations."
                                ),
                                "suggestion": (
                                    "Consider using stronger hashing algorithms like SHA-256 or SHA-3. "
                                    "Additionally, review the cryptographic standards for your application "
                                    "to ensure compliance with modern security practices."
                                )
                            }
                            vulnerabilities.append(vulnerability_info)

    return vulnerabilities

# Example usage
directory_to_scan = '/content/drive/MyDrive/test'
results = find_insecure_crypto(directory_to_scan)

if results:
    for result in results:
        print(f"File: {result['file']}")
        print(f"Function: {result['function']}")
        print(f"Explanation: {result['explanation']}")
        print(f"Suggestion: {result['suggestion']}")
        print("-" * 80)  # Separator for better readability
else:
    print("No vulnerabilities found.")
# Out:
# File: /content/drive/MyDrive/test/sample.cpp
# Function: md5
# Explanation: md5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: SHA1
# Explanation: SHA1 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: EVP_md5
# Explanation: EVP_md5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: MD5
# Explanation: MD5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample.cpp
# Function: EVP_sha1
# Explanation: EVP_sha1 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample2.cpp
# Function: EVP_md5
# Explanation: EVP_md5 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------
# File: /content/drive/MyDrive/test/sample2.cpp
# Function: EVP_sha1
# Explanation: EVP_sha1 is an insecure cryptographic function. Both MD5 and SHA-1 are considered weak due to vulnerabilities that allow for collision attacks, where two different inputs produce the same hash. This can lead to security issues such as forgery of digital signatures and data integrity violations.
# Suggestion: Consider using stronger hashing algorithms like SHA-256 or SHA-3. Additionally, review the cryptographic standards for your application to ensure compliance with modern security practices.
# --------------------------------------------------------------------------------

# %%
import subprocess

def run_cppcheck(file_path):
    command = ['cppcheck', '--enable=all', '--inconclusive', '--std=c++11', '--verbose', file_path]
    try:
        result = subprocess.run(command, capture_output=True, text=True, check=True)
        print("Cppcheck Output:\n", result.stdout)
    except subprocess.CalledProcessError as e:
        print("Error running Cppcheck:\n", e.stderr)

# Example usage
cpp_file = '/content/drive/MyDrive/test/sample.cpp'
run_cppcheck(cpp_file)
# Out:
# Cppcheck Output:
#  Checking /content/drive/MyDrive/test/sample.cpp ...
# Defines:
# Undefines:
# Includes:
# Platform:Native

# %%
# !apt-get install valgrind
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   gdb libbabeltrace1 libc6-dbg libdebuginfod-common libdebuginfod1 libipt2
#   libsource-highlight-common libsource-highlight4v5
# Suggested packages:
#   gdb-doc gdbserver valgrind-dbg valgrind-mpi kcachegrind alleyoop valkyrie
# The following NEW packages will be installed:
#   gdb libbabeltrace1 libc6-dbg libdebuginfod-common libdebuginfod1 libipt2
#   libsource-highlight-common libsource-highlight4v5 valgrind
# 0 upgraded, 9 newly installed, 0 to remove and 50 not upgraded.
# Need to get 32.3 MB of archives.
# After this operation, 111 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdebuginfod-common all 0.186-1build1 [7,878 B]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libbabeltrace1 amd64 1.5.8-2build1 [160 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdebuginfod1 amd64 0.186-1build1 [12.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libipt2 amd64 2.0.5-1 [46.4 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsource-highlight-common all 3.1.9-4.1build2 [64.5 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsource-highlight4v5 amd64 3.1.9-4.1build2 [207 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gdb amd64 12.1-0ubuntu1~22.04.2 [3,920 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc6-dbg amd64 2.35-0ubuntu3.8 [13.8 MB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 valgrind amd64 1:3.18.1-1ubuntu2 [14.1 MB]
# Fetched 32.3 MB in 1s (51.7 MB/s)
# Preconfiguring packages ...
# Selecting previously unselected package libdebuginfod-common.
# (Reading database ... 123629 files and directories currently installed.)
# Preparing to unpack .../0-libdebuginfod-common_0.186-1build1_all.deb ...
# Unpacking libdebuginfod-common (0.186-1build1) ...
# Selecting previously unselected package libbabeltrace1:amd64.
# Preparing to unpack .../1-libbabeltrace1_1.5.8-2build1_amd64.deb ...
# Unpacking libbabeltrace1:amd64 (1.5.8-2build1) ...
# Selecting previously unselected package libdebuginfod1:amd64.
# Preparing to unpack .../2-libdebuginfod1_0.186-1build1_amd64.deb ...
# Unpacking libdebuginfod1:amd64 (0.186-1build1) ...
# Selecting previously unselected package libipt2.
# Preparing to unpack .../3-libipt2_2.0.5-1_amd64.deb ...
# Unpacking libipt2 (2.0.5-1) ...
# Selecting previously unselected package libsource-highlight-common.
# Preparing to unpack .../4-libsource-highlight-common_3.1.9-4.1build2_all.deb ...
# Unpacking libsource-highlight-common (3.1.9-4.1build2) ...
# Selecting previously unselected package libsource-highlight4v5.
# Preparing to unpack .../5-libsource-highlight4v5_3.1.9-4.1build2_amd64.deb ...
# Unpacking libsource-highlight4v5 (3.1.9-4.1build2) ...
# Selecting previously unselected package gdb.
# Preparing to unpack .../6-gdb_12.1-0ubuntu1~22.04.2_amd64.deb ...
# Unpacking gdb (12.1-0ubuntu1~22.04.2) ...
# Selecting previously unselected package libc6-dbg:amd64.
# Preparing to unpack .../7-libc6-dbg_2.35-0ubuntu3.8_amd64.deb ...
# Unpacking libc6-dbg:amd64 (2.35-0ubuntu3.8) ...
# Selecting previously unselected package valgrind.
# Preparing to unpack .../8-valgrind_1%3a3.18.1-1ubuntu2_amd64.deb ...
# Unpacking valgrind (1:3.18.1-1ubuntu2) ...
# Setting up libdebuginfod-common (0.186-1build1) ...
#
# Creating config file /etc/profile.d/debuginfod.sh with new version
#
# Creating config file /etc/profile.d/debuginfod.csh with new version
# Setting up libdebuginfod1:amd64 (0.186-1build1) ...
# Setting up libsource-highlight-common (3.1.9-4.1build2) ...
# Setting up libc6-dbg:amd64 (2.35-0ubuntu3.8) ...
# Setting up libipt2 (2.0.5-1) ...
# Setting up libbabeltrace1:amd64 (1.5.8-2build1) ...
# Setting up valgrind (1:3.18.1-1ubuntu2) ...
# Setting up libsource-highlight4v5 (3.1.9-4.1build2) ...
# Setting up gdb (12.1-0ubuntu1~22.04.2) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Step 2: Define the path to your C++ file in Google Drive
cpp_file_path = '/content/drive/MyDrive/test/sample.cpp'

# Step 3: Suggest running analysis tools
def suggest_analysis(file_name):
    print(f"\nTo check for race conditions in {file_name}, run the following commands:")
    print(f"1. Using ThreadSanitizer:\n   !g++ -fsanitize=thread {file_name} -o output_file && ./output_file")
    print(f"2. Using Helgrind:\n   !valgrind --tool=helgrind ./output_file")

# Step 4: Analyze the file
suggest_analysis(cpp_file_path)

# Step 5: Compile and run the analysis (uncomment the next line to execute)
# !g++ -fsanitize=thread {cpp_file_path} -o output_file && ./output_file
# !valgrind --tool=helgrind ./output_file
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# To check for race conditions in /content/drive/MyDrive/test/sample.cpp, run the following commands:
# 1. Using ThreadSanitizer:
#    !g++ -fsanitize=thread /content/drive/MyDrive/test/sample.cpp -o output_file && ./output_file
# 2. Using Helgrind:
#    !valgrind --tool=helgrind ./output_file
# /content/drive/MyDrive/test/sample.cpp: In function ‘void md5_hash_function()’:
# /content/drive/MyDrive/test/sample.cpp:33:8: warning: ‘unsigned char* MD5(const unsigned char*, size_t, unsigned char*)’ is deprecated: Since OpenSSL 3.0 [-Wdeprecated-declarations]
#    33 |     MD5((unsigned char*)input, strlen(input), output); // Deprecated call
#       |     ~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /content/drive/MyDrive/test/sample.cpp:5:
# /usr/include/openssl/md5.h:52:38: note: declared here
#    52 | OSSL_DEPRECATEDIN_3_0 unsigned char *MD5(const unsigned char *d, size_t n,
#       |                                      ^~~
# /usr/bin/ld: /tmp/ccRS9vjm.o: in function `md5_hash_function()':
# sample.cpp:(.text+0x18a): undefined reference to `MD5'
# /usr/bin/ld: /tmp/ccRS9vjm.o: in function `sha1_hash_function()':
# sample.cpp:(.text+0x294): undefined reference to `SHA1'
# /usr/bin/ld: /tmp/ccRS9vjm.o: in function `md5_hash_function_evp()':
# sample.cpp:(.text+0x381): undefined reference to `EVP_MD_CTX_new'
# /usr/bin/ld: sample.cpp:(.text+0x3c1): undefined reference to `EVP_md5'
# /usr/bin/ld: sample.cpp:(.text+0x3d8): undefined reference to `EVP_DigestInit_ex'
# /usr/bin/ld: sample.cpp:(.text+0x3ff): undefined reference to `EVP_DigestUpdate'
# /usr/bin/ld: sample.cpp:(.text+0x41b): undefined reference to `EVP_DigestFinal_ex'
# /usr/bin/ld: sample.cpp:(.text+0x467): undefined reference to `EVP_MD_CTX_free'
# /usr/bin/ld: sample.cpp:(.text+0x478): undefined reference to `EVP_MD_CTX_free'
# /usr/bin/ld: /tmp/ccRS9vjm.o: in function `sha1_hash_function_evp()':
# sample.cpp:(.text+0x56e): undefined reference to `EVP_MD_CTX_new'
# /usr/bin/ld: sample.cpp:(.text+0x5ae): undefined reference to `EVP_sha1'
# /usr/bin/ld: sample.cpp:(.text+0x5c5): undefined reference to `EVP_DigestInit_ex'
# /usr/bin/ld: sample.cpp:(.text+0x5ec): undefined reference to `EVP_DigestUpdate'
# /usr/bin/ld: sample.cpp:(.text+0x608): undefined reference to `EVP_DigestFinal_ex'
# /usr/bin/ld: sample.cpp:(.text+0x654): undefined reference to `EVP_MD_CTX_free'
# /usr/bin/ld: sample.cpp:(.text+0x665): undefined reference to `EVP_MD_CTX_free'
# collect2: error: ld returned 1 exit status
# /bin/bash: line 1: valgrind: command not found

# %%
# !apt-get update
# !apt-get install -y libssl-dev
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Ign:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,032 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,595 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,400 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,648 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,450 kB]
# Fetched 16.5 MB in 4s (4,689 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libssl-dev is already the newest version (3.0.2-0ubuntu1.18).
# 0 upgraded, 0 newly installed, 0 to remove and 50 not upgraded.

# %%
# !openssl version
# Out:
# OpenSSL 3.0.2 15 Mar 2022 (Library: OpenSSL 3.0.2 15 Mar 2022)

# %%
# !g++ {cpp_file_path} -o sample -lssl -lcrypto -pthread
# Out:
# /content/drive/MyDrive/test/sample.cpp: In function ‘void md5_hash_function()’:
# /content/drive/MyDrive/test/sample.cpp:33:8: warning: ‘unsigned char* MD5(const unsigned char*, size_t, unsigned char*)’ is deprecated: Since OpenSSL 3.0 [-Wdeprecated-declarations]
#    33 |     MD5((unsigned char*)input, strlen(input), output); // Deprecated call
#       |     ~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /content/drive/MyDrive/test/sample.cpp:5:
# /usr/include/openssl/md5.h:52:38: note: declared here
#    52 | OSSL_DEPRECATEDIN_3_0 unsigned char *MD5(const unsigned char *d, size_t n,
#       |                                      ^~~

# %%
# !./sample
# Out:
# Final shared_data (unsafe): 263476
# Final shared_data (safe): 300000
# MD5 (deprecated): 8d777f385d3dfec8815d20f7496026dc
# SHA-1 (deprecated): a17c9aaa61e80a1bf71d0d850af4e5baa9800bbd
# MD5 (EVP): 8d777f385d3dfec8815d20f7496026dc
# SHA-1 (EVP): a17c9aaa61e80a1bf71d0d850af4e5baa9800bbd

# %%
# !valgrind --tool=helgrind ./sample
# Out:
# ==2261== Helgrind, a thread error detector
# ==2261== Copyright (C) 2007-2017, and GNU GPL'd, by OpenWorks LLP et al.
# ==2261== Using Valgrind-3.18.1 and LibVEX; rerun with -h for copyright info
# ==2261== Command: ./sample
# ==2261==
# ==2261== ---Thread-Announcement------------------------------------------
# ==2261==
# ==2261== Thread #3 was created
# ==2261==    at 0x502D9F3: clone (clone.S:76)
# ==2261==    by 0x502E8EE: __clone_internal (clone-internal.c:83)
# ==2261==    by 0x4F9C6D8: create_thread (pthread_create.c:295)
# ==2261==    by 0x4F9D1FF: pthread_create@@GLIBC_2.34 (pthread_create.c:828)
# ==2261==    by 0x4853767: ??? (in /usr/libexec/valgrind/vgpreload_helgrind-amd64-linux.so)
# ==2261==    by 0x4D98328: std::thread::_M_start_thread(std::unique_ptr<std::thread::_State, std::default_delete<std::thread::_State> >, void (*)()) (in /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30)
# ==2261==    by 0x10BBF7: std::thread::thread<void (&)(), , void>(void (&)()) (in /content/sample)
# ==2261==    by 0x10B89E: void __gnu_cxx::new_allocator<std::thread>::construct<std::thread, void (&)()>(std::thread*, void (&)()) (in /content/sample)
# ==2261==    by 0x10B497: void std::allocator_traits<std::allocator<std::thread> >::construct<std::thread, void (&)()>(std::allocator<std::thread>&, std::thread*, void (&)()) (in /content/sample)
# ==2261==    by 0x10B56D: void std::vector<std::thread, std::allocator<std::thread> >::_M_realloc_insert<void (&)()>(__gnu_cxx::__normal_iterator<std::thread*, std::vector<std::thread, std::allocator<std::thread> > >, void (&)()) (in /content/sample)
# ==2261==    by 0x10B20B: std::thread& std::vector<std::thread, std::allocator<std::thread> >::emplace_back<void (&)()>(void (&)()) (in /content/sample)
# ==2261==    by 0x10AB13: main (in /content/sample)
# ==2261==
# ==2261== ---Thread-Announcement------------------------------------------
# ==2261==
# ==2261== Thread #2 was created
# ==2261==    at 0x502D9F3: clone (clone.S:76)
# ==2261==    by 0x502E8EE: __clone_internal (clone-internal.c:83)
# ==2261==    by 0x4F9C6D8: create_thread (pthread_create.c:295)
# ==2261==    by 0x4F9D1FF: pthread_create@@GLIBC_2.34 (pthread_create.c:828)
# ==2261==    by 0x4853767: ??? (in /usr/libexec/valgrind/vgpreload_helgrind-amd64-linux.so)
# ==2261==    by 0x4D98328: std::thread::_M_start_thread(std::unique_ptr<std::thread::_State, std::default_delete<std::thread::_State> >, void (*)()) (in /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30)
# ==2261==    by 0x10BBF7: std::thread::thread<void (&)(), , void>(void (&)()) (in /content/sample)
# ==2261==    by 0x10B89E: void __gnu_cxx::new_allocator<std::thread>::construct<std::thread, void (&)()>(std::thread*, void (&)()) (in /content/sample)
# ==2261==    by 0x10B497: void std::allocator_traits<std::allocator<std::thread> >::construct<std::thread, void (&)()>(std::allocator<std::thread>&, std::thread*, void (&)()) (in /content/sample)
# ==2261==    by 0x10B56D: void std::vector<std::thread, std::allocator<std::thread> >::_M_realloc_insert<void (&)()>(__gnu_cxx::__normal_iterator<std::thread*, std::vector<std::thread, std::allocator<std::thread> > >, void (&)()) (in /content/sample)
# ==2261==    by 0x10B20B: std::thread& std::vector<std::thread, std::allocator<std::thread> >::emplace_back<void (&)()>(void (&)()) (in /content/sample)
# ==2261==    by 0x10AB13: main (in /content/sample)
# ==2261==
# ==2261== ----------------------------------------------------------------
# ==2261==
# ==2261== Possible data race during read of size 4 at 0x110280 by thread #3
# ==2261== Locks held: none
# ==2261==    at 0x10A565: increment_shared_data_unsafe() (in /content/sample)
# ==2261==    by 0x10C6DA: void std::__invoke_impl<void, void (*)()>(std::__invoke_other, void (*&&)()) (in /content/sample)
# ==2261==    by 0x10C686: std::__invoke_result<void (*)()>::type std::__invoke<void (*)()>(void (*&&)()) (in /content/sample)
# ==2261==    by 0x10C627: void std::thread::_Invoker<std::tuple<void (*)()> >::_M_invoke<0ul>(std::_Index_tuple<0ul>) (in /content/sample)
# ==2261==    by 0x10C5F7: std::thread::_Invoker<std::tuple<void (*)()> >::operator()() (in /content/sample)
# ==2261==    by 0x10C5D7: std::thread::_State_impl<std::thread::_Invoker<std::tuple<void (*)()> > >::_M_run() (in /content/sample)
# ==2261==    by 0x4D98252: ??? (in /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30)
# ==2261==    by 0x485396A: ??? (in /usr/libexec/valgrind/vgpreload_helgrind-amd64-linux.so)
# ==2261==    by 0x4F9CAC2: start_thread (pthread_create.c:442)
# ==2261==    by 0x502DA03: clone (clone.S:100)
# ==2261==
# ==2261== This conflicts with a previous write of size 4 by thread #2
# ==2261== Locks held: none
# ==2261==    at 0x10A56E: increment_shared_data_unsafe() (in /content/sample)
# ==2261==    by 0x10C6DA: void std::__invoke_impl<void, void (*)()>(std::__invoke_other, void (*&&)()) (in /content/sample)
# ==2261==    by 0x10C686: std::__invoke_result<void (*)()>::type std::__invoke<void (*)()>(void (*&&)()) (in /content/sample)
# ==2261==    by 0x10C627: void std::thread::_Invoker<std::tuple<void (*)()> >::_M_invoke<0ul>(std::_Index_tuple<0ul>) (in /content/sample)
# ==2261==    by 0x10C5F7: std::thread::_Invoker<std::tuple<void (*)()> >::operator()() (in /content/sample)
# ==2261==    by 0x10C5D7: std::thread::_State_impl<std::thread::_Invoker<std::tuple<void (*)()> > >::_M_run() (in /content/sample)
# ==2261==    by 0x4D98252: ??? (in /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30)
# ==2261==    by 0x485396A: ??? (in /usr/libexec/valgrind/vgpreload_helgrind-amd64-linux.so)
# ==2261==  Address 0x110280 is 0 bytes inside data symbol "shared_data_unsafe"
# ==2261==
# ==2261== ----------------------------------------------------------------
# ==2261==
# ==2261== Possible data race during write of size 4 at 0x110280 by thread #3
# ==2261== Locks held: none
# ==2261==    at 0x10A56E: increment_shared_data_unsafe() (in /content/sample)
# ==2261==    by 0x10C6DA: void std::__invoke_impl<void, void (*)()>(std::__invoke_other, void (*&&)()) (in /content/sample)
# ==2261==    by 0x10C686: std::__invoke_result<void (*)()>::type std::__invoke<void (*)()>(void (*&&)()) (in /content/sample)
# ==2261==    by 0x10C627: void std::thread::_Invoker<std::tuple<void (*)()> >::_M_invoke<0ul>(std::_Index_tuple<0ul>) (in /content/sample)
# ==2261==    by 0x10C5F7: std::thread::_Invoker<std::tuple<void (*)()> >::operator()() (in /content/sample)
# ==2261==    by 0x10C5D7: std::thread::_State_impl<std::thread::_Invoker<std::tuple<void (*)()> > >::_M_run() (in /content/sample)
# ==2261==    by 0x4D98252: ??? (in /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30)
# ==2261==    by 0x485396A: ??? (in /usr/libexec/valgrind/vgpreload_helgrind-amd64-linux.so)
# ==2261==    by 0x4F9CAC2: start_thread (pthread_create.c:442)
# ==2261==    by 0x502DA03: clone (clone.S:100)
# ==2261==
# ==2261== This conflicts with a previous write of size 4 by thread #2
# ==2261== Locks held: none
# ==2261==    at 0x10A56E: increment_shared_data_unsafe() (in /content/sample)
# ==2261==    by 0x10C6DA: void std::__invoke_impl<void, void (*)()>(std::__invoke_other, void (*&&)()) (in /content/sample)
# ==2261==    by 0x10C686: std::__invoke_result<void (*)()>::type std::__invoke<void (*)()>(void (*&&)()) (in /content/sample)
# ==2261==    by 0x10C627: void std::thread::_Invoker<std::tuple<void (*)()> >::_M_invoke<0ul>(std::_Index_tuple<0ul>) (in /content/sample)
# ==2261==    by 0x10C5F7: std::thread::_Invoker<std::tuple<void (*)()> >::operator()() (in /content/sample)
# ==2261==    by 0x10C5D7: std::thread::_State_impl<std::thread::_Invoker<std::tuple<void (*)()> > >::_M_run() (in /content/sample)
# ==2261==    by 0x4D98252: ??? (in /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30)
# ==2261==    by 0x485396A: ??? (in /usr/libexec/valgrind/vgpreload_helgrind-amd64-linux.so)
# ==2261==  Address 0x110280 is 0 bytes inside data symbol "shared_data_unsafe"
# ==2261==
# Final shared_data (unsafe): 300000
# Final shared_data (safe): 300000
# MD5 (deprecated): 8d777f385d3dfec8815d20f7496026dc
# SHA-1 (deprecated): a17c9aaa61e80a1bf71d0d850af4e5baa9800bbd
# MD5 (EVP): 8d777f385d3dfec8815d20f7496026dc
# SHA-1 (EVP): a17c9aaa61e80a1bf71d0d850af4e5baa9800bbd
# ==2261==
# ==2261== Use --history-level=approx or =none to gain increased speed, at
# ==2261== the cost of reduced accuracy of conflicting-access information
# ==2261== For lists of detected and suppressed errors, rerun with: -s
# ==2261== ERROR SUMMARY: 4 errors from 2 contexts (suppressed: 422481 from 7)

# %%
cpp_file_path = '/content/drive/MyDrive/test/sample2.cpp'
# !g++ {cpp_file_path} -o sample -lssl -lcrypto -pthread

# %%
# !./sample
# Out:
# Final shared_data (safe): 300000
# Hash-1: 8d777f385d3dfec8815d20f7496026dc
# Hash-2: a17c9aaa61e80a1bf71d0d850af4e5baa9800bbd

# %%
# !valgrind --tool=helgrind ./sample
# Out:
# ==3464== Helgrind, a thread error detector
# ==3464== Copyright (C) 2007-2017, and GNU GPL'd, by OpenWorks LLP et al.
# ==3464== Using Valgrind-3.18.1 and LibVEX; rerun with -h for copyright info
# ==3464== Command: ./sample
# ==3464==
# Final shared_data (safe): 300000
# Hash-1: 8d777f385d3dfec8815d20f7496026dc
# Hash-2: a17c9aaa61e80a1bf71d0d850af4e5baa9800bbd
# ==3464==
# ==3464== Use --history-level=approx or =none to gain increased speed, at
# ==3464== the cost of reduced accuracy of conflicting-access information
# ==3464== For lists of detected and suppressed errors, rerun with: -s
# ==3464== ERROR SUMMARY: 0 errors from 0 contexts (suppressed: 882560 from 7)

# %%
cpp_file_path = '/content/drive/MyDrive/test/sample3.cpp'
# !g++ {cpp_file_path} -o sample -lssl -lcrypto -pthread

# %%
# !./sample
# Out:
# Final shared_data (safe): 300000
# SHA-256: 3a6eb0790f39ac87c94f3856b2dd2c5d110e6811602261a9a923d3bb23adc8b7

# %%
# !valgrind --tool=helgrind ./sample
# Out:
# ==29729== Helgrind, a thread error detector
# ==29729== Copyright (C) 2007-2017, and GNU GPL'd, by OpenWorks LLP et al.
# ==29729== Using Valgrind-3.18.1 and LibVEX; rerun with -h for copyright info
# ==29729== Command: ./sample
# ==29729==
# Final shared_data (safe): 300000
# SHA-256: 3a6eb0790f39ac87c94f3856b2dd2c5d110e6811602261a9a923d3bb23adc8b7
# ==29729==
# ==29729== Use --history-level=approx or =none to gain increased speed, at
# ==29729== the cost of reduced accuracy of conflicting-access information
# ==29729== For lists of detected and suppressed errors, rerun with: -s
# ==29729== ERROR SUMMARY: 0 errors from 0 contexts (suppressed: 873793 from 7)

# %%
cpp_file_path = '/content/drive/MyDrive/test/sample4.cpp'
# !g++ {cpp_file_path} -o sample -lssl -lcrypto -pthread

# %%
# !./sample
# Out:
# Final counter value: 154322

# %%
# !valgrind --tool=helgrind ./sample
# Out:
# ==35331== Helgrind, a thread error detector
# ==35331== Copyright (C) 2007-2017, and GNU GPL'd, by OpenWorks LLP et al.
# ==35331== Using Valgrind-3.18.1 and LibVEX; rerun with -h for copyright info
# ==35331== Command: ./sample
# ==35331==
# ==35331== ---Thread-Announcement------------------------------------------
# ==35331==
# ==35331== Thread #3 was created
# ==35331==    at 0x4BE99F3: clone (clone.S:76)
# ==35331==    by 0x4BEA8EE: __clone_internal (clone-internal.c:83)
# ==35331==    by 0x4B586D8: create_thread (pthread_create.c:295)
# ==35331==    by 0x4B591FF: pthread_create@@GLIBC_2.34 (pthread_create.c:828)
# ==35331==    by 0x4853767: ??? (in /usr/libexec/valgrind/vgpreload_helgrind-amd64-linux.so)
# ==35331==    by 0x4954328: std::thread::_M_start_thread(std::unique_ptr<std::thread::_State, std::default_delete<std::thread::_State> >, void (*)()) (in /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30)
# ==35331==    by 0x1095B7: std::thread::thread<void (&)(), , void>(void (&)()) (in /content/sample)
# ==35331==    by 0x109341: main (in /content/sample)
# ==35331==
# ==35331== ---Thread-Announcement------------------------------------------
# ==35331==
# ==35331== Thread #2 was created
# ==35331==    at 0x4BE99F3: clone (clone.S:76)
# ==35331==    by 0x4BEA8EE: __clone_internal (clone-internal.c:83)
# ==35331==    by 0x4B586D8: create_thread (pthread_create.c:295)
# ==35331==    by 0x4B591FF: pthread_create@@GLIBC_2.34 (pthread_create.c:828)
# ==35331==    by 0x4853767: ??? (in /usr/libexec/valgrind/vgpreload_helgrind-amd64-linux.so)
# ==35331==    by 0x4954328: std::thread::_M_start_thread(std::unique_ptr<std::thread::_State, std::default_delete<std::thread::_State> >, void (*)()) (in /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30)
# ==35331==    by 0x1095B7: std::thread::thread<void (&)(), , void>(void (&)()) (in /content/sample)
# ==35331==    by 0x10932B: main (in /content/sample)
# ==35331==
# ==35331== ----------------------------------------------------------------
# ==35331==
# ==35331== Possible data race during read of size 4 at 0x10C154 by thread #3
# ==35331== Locks held: none
# ==35331==    at 0x1092DA: increment() (in /content/sample)
# ==35331==    by 0x109C1E: void std::__invoke_impl<void, void (*)()>(std::__invoke_other, void (*&&)()) (in /content/sample)
# ==35331==    by 0x109BCA: std::__invoke_result<void (*)()>::type std::__invoke<void (*)()>(void (*&&)()) (in /content/sample)
# ==35331==    by 0x109B6B: void std::thread::_Invoker<std::tuple<void (*)()> >::_M_invoke<0ul>(std::_Index_tuple<0ul>) (in /content/sample)
# ==35331==    by 0x109B3B: std::thread::_Invoker<std::tuple<void (*)()> >::operator()() (in /content/sample)
# ==35331==    by 0x109B1B: std::thread::_State_impl<std::thread::_Invoker<std::tuple<void (*)()> > >::_M_run() (in /content/sample)
# ==35331==    by 0x4954252: ??? (in /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30)
# ==35331==    by 0x485396A: ??? (in /usr/libexec/valgrind/vgpreload_helgrind-amd64-linux.so)
# ==35331==    by 0x4B58AC2: start_thread (pthread_create.c:442)
# ==35331==    by 0x4BE9A03: clone (clone.S:100)
# ==35331==
# ==35331== This conflicts with a previous write of size 4 by thread #2
# ==35331== Locks held: none
# ==35331==    at 0x1092E3: increment() (in /content/sample)
# ==35331==    by 0x109C1E: void std::__invoke_impl<void, void (*)()>(std::__invoke_other, void (*&&)()) (in /content/sample)
# ==35331==    by 0x109BCA: std::__invoke_result<void (*)()>::type std::__invoke<void (*)()>(void (*&&)()) (in /content/sample)
# ==35331==    by 0x109B6B: void std::thread::_Invoker<std::tuple<void (*)()> >::_M_invoke<0ul>(std::_Index_tuple<0ul>) (in /content/sample)
# ==35331==    by 0x109B3B: std::thread::_Invoker<std::tuple<void (*)()> >::operator()() (in /content/sample)
# ==35331==    by 0x109B1B: std::thread::_State_impl<std::thread::_Invoker<std::tuple<void (*)()> > >::_M_run() (in /content/sample)
# ==35331==    by 0x4954252: ??? (in /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30)
# ==35331==    by 0x485396A: ??? (in /usr/libexec/valgrind/vgpreload_helgrind-amd64-linux.so)
# ==35331==  Address 0x10c154 is 0 bytes inside data symbol "counter"
# ==35331==
# ==35331== ----------------------------------------------------------------
# ==35331==
# ==35331== Possible data race during write of size 4 at 0x10C154 by thread #3
# ==35331== Locks held: none
# ==35331==    at 0x1092E3: increment() (in /content/sample)
# ==35331==    by 0x109C1E: void std::__invoke_impl<void, void (*)()>(std::__invoke_other, void (*&&)()) (in /content/sample)
# ==35331==    by 0x109BCA: std::__invoke_result<void (*)()>::type std::__invoke<void (*)()>(void (*&&)()) (in /content/sample)
# ==35331==    by 0x109B6B: void std::thread::_Invoker<std::tuple<void (*)()> >::_M_invoke<0ul>(std::_Index_tuple<0ul>) (in /content/sample)
# ==35331==    by 0x109B3B: std::thread::_Invoker<std::tuple<void (*)()> >::operator()() (in /content/sample)
# ==35331==    by 0x109B1B: std::thread::_State_impl<std::thread::_Invoker<std::tuple<void (*)()> > >::_M_run() (in /content/sample)
# ==35331==    by 0x4954252: ??? (in /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30)
# ==35331==    by 0x485396A: ??? (in /usr/libexec/valgrind/vgpreload_helgrind-amd64-linux.so)
# ==35331==    by 0x4B58AC2: start_thread (pthread_create.c:442)
# ==35331==    by 0x4BE9A03: clone (clone.S:100)
# ==35331==
# ==35331== This conflicts with a previous write of size 4 by thread #2
# ==35331== Locks held: none
# ==35331==    at 0x1092E3: increment() (in /content/sample)
# ==35331==    by 0x109C1E: void std::__invoke_impl<void, void (*)()>(std::__invoke_other, void (*&&)()) (in /content/sample)
# ==35331==    by 0x109BCA: std::__invoke_result<void (*)()>::type std::__invoke<void (*)()>(void (*&&)()) (in /content/sample)
# ==35331==    by 0x109B6B: void std::thread::_Invoker<std::tuple<void (*)()> >::_M_invoke<0ul>(std::_Index_tuple<0ul>) (in /content/sample)
# ==35331==    by 0x109B3B: std::thread::_Invoker<std::tuple<void (*)()> >::operator()() (in /content/sample)
# ==35331==    by 0x109B1B: std::thread::_State_impl<std::thread::_Invoker<std::tuple<void (*)()> > >::_M_run() (in /content/sample)
# ==35331==    by 0x4954252: ??? (in /usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30)
# ==35331==    by 0x485396A: ??? (in /usr/libexec/valgrind/vgpreload_helgrind-amd64-linux.so)
# ==35331==  Address 0x10c154 is 0 bytes inside data symbol "counter"
# ==35331==
# Final counter value: 200000
# ==35331==
# ==35331== Use --history-level=approx or =none to gain increased speed, at
# ==35331== the cost of reduced accuracy of conflicting-access information
# ==35331== For lists of detected and suppressed errors, rerun with: -s
# ==35331== ERROR SUMMARY: 2 errors from 2 contexts (suppressed: 0 from 0)

# %%
cpp_file_path = '/content/drive/MyDrive/test/sample5.cpp'
# !g++ {cpp_file_path} -o sample -lssl -lcrypto -pthread

# %%
# !./sample
# Out:
# Final counter value: 200000

# %%
# !valgrind --tool=helgrind ./sample
# Out:
# ==35537== Helgrind, a thread error detector
# ==35537== Copyright (C) 2007-2017, and GNU GPL'd, by OpenWorks LLP et al.
# ==35537== Using Valgrind-3.18.1 and LibVEX; rerun with -h for copyright info
# ==35537== Command: ./sample
# ==35537==
# Final counter value: 200000
# ==35537==
# ==35537== Use --history-level=approx or =none to gain increased speed, at
# ==35537== the cost of reduced accuracy of conflicting-access information
# ==35537== For lists of detected and suppressed errors, rerun with: -s
# ==35537== ERROR SUMMARY: 0 errors from 0 contexts (suppressed: 580236 from 7)
